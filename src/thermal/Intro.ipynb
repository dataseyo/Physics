# %%
from manim import *
import numpy as np
# Out:
# Manim Community v0.16.0.post0

# %%
# %%manim -qh -r 1080,1920 Spins
#
# # generate a bunch of randomly facing arrows in the center of the screen
# class Spins(Scene):
#     def construct(self):
#         def create_arrows(arrows=[], n=11):
#             '''
#             params:
#             - arrows: "u" - up, "d" - down
#             - n: number of arrows
#             '''
#             group = VGroup()
#             # generate n arrows randomly
#             if not arrows:
#                 for i in np.arange(1, n, 1):
#                     rand = np.random.randint(10)
#
#                     if rand > 5:
#                         group += Arrow(start=ORIGIN, end=config.top).shift(RIGHT*i)
#                     else:
#                         group += Arrow(start=config.top, end=ORIGIN).shift(RIGHT*i)
#             # generate n arrows by evaluating the arrows array parameter
#             else:
#                 for i, arr in enumerate(arrows):
#                     if arr == "u":
#                         group += Arrow(start=ORIGIN, end=config.top).shift(RIGHT*i)
#                     else:
#                         group += Arrow(start=config.top, end=ORIGIN).shift(RIGHT*i)
#
#             return group
#
#         arrows = create_arrows(
#             ["u", "d", "u", "d", "d", "u", "d", "u", "u", "u"]
#         )
#         arrows.center()
#
#         self.play(Write(arrows))
# Out:
# [12/19/23 18:00:04] INFO     Animation 0 : Partial movie file written in                   ]8;id=875183;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=791620;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\partial_movie_files\Spins\4222611999_955641823_223132
#                              457.mp4'
# [12/19/23 18:00:05] INFO     Combining to Movie file.                                      ]8;id=963711;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=433461;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#607\607]8;;\
#                     INFO                                                                   ]8;id=32619;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=16820;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\Spins.mp4'
#                     INFO     Rendered Spins                                                            ]8;id=211927;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=719056;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 1 animations
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-146-beaa7e6fa040> in <module>
# ----> 1 get_ipython().run_cell_magic('manim', '-qh -r 1080,1920 Spins', '\n# generate a bunch of randomly facing arrows in the center of the screen\nclass Spins(Scene):           \n    def construct(self):\n        def create_arrows(arrows=[], n=11):\n            \'\'\'\n            params:\n            - arrows: "u" - up, "d" - down\n            - n: number of arrows\n            \'\'\'\n            group = VGroup()\n            # generate n arrows randomly\n            if not arrows:\n                for i in np.arange(1, n, 1):\n                    rand = np.random.randint(10)\n\n                    if rand > 5:\n                        group += Arrow(start=ORIGIN, end=config.top).shift(RIGHT*i)\n                    else:\n                        group += Arrow(start=config.top, end=ORIGIN).shift(RIGHT*i)\n            # generate n arrows by evaluating the arrows array parameter\n            else:\n                for i, arr in enumerate(arrows):\n                    if arr == "u":\n                        group += Arrow(start=ORIGIN, end=config.top).shift(RIGHT*i)\n                    else: \n                        group += Arrow(start=config.top, end=ORIGIN).shift(RIGHT*i) \n\n            return group\n\n        arrows = create_arrows(\n            ["u", "d", "u", "d", "d", "u", "d", "u", "u", "u"]\n        )\n        arrows.center()\n\n        self.play(Write(arrows))\n\n')
#
# c:\Users\Zach\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2360             with self.builtin_trap:
#    2361                 args = (magic_arg_s, cell)
# -> 2362                 result = fn(*args, **kwargs)
#    2363             return result
#    2364
#
# c:\Users\Zach\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# c:\Users\Zach\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\ipython_magic.py in manim(self, line, cell, local_ns)
#     189                         tmpfile,
#     190                         html_attributes=f'controls autoplay loop style="max-width: {config["media_width"]};"',
# --> 191                         embed=embed,
#     192                     )
#     193
#
# TypeError: __init__() got an unexpected keyword argument 'html_attributes'

# %%
# %%manim -qm ParticlesInABox
#
# class ParticlesInABox(Scene):
#     def construct(self):
#         size = 6
#         box = Rectangle(width=size, height=size)
#
#         def particle_updater(obj):
#             x_coord = obj.get_x()
#             y_coord = obj.get_y()
#
#             d1 = np.random.uniform(low=-0.04, high=0.04)
#             d2 = np.random.uniform(low=-0.03, high=0.03)
#             x_new = x_coord+d1 if (x_coord+d1 < 6) else x_coord-d1
#             y_new = y_coord+d2 if (y_coord+d2 < 6) else y_coord-d2
#             obj.move_to([x_new, y_new, 0])
#
#         def generate_particles(N, update=True, pos=[-2.4, 2.4]):
#             particles = VGroup()
#             for i in range(N):
#                 # generate dot with random color
#                 rand = lambda: np.random.uniform(low=0.0, high=1.0)
#                 color = rgb_to_color([rand(), rand(), rand()])
#
#                 dot = Dot(color=color).scale(.5)
#
#                 # random position to dot
#                 loc = np.array(
#                     [
#                         np.random.uniform(low=pos[0], high=pos[1]),
#                         np.random.uniform(low=pos[0], high=pos[1]),
#                         0
#                     ]
#                 )
#
#                 dot.move_to(loc)
#
#                 if update:
#                     dot.add_updater(particle_updater)
#                 particles += dot
#
#             return particles
#
#         p1 = generate_particles(1, pos=[-.02, .02])
#         p2 = generate_particles(2, pos=[-.04, .04])
#         p3 = generate_particles(10, pos=[-.2, .2])
#         p4 = generate_particles(350)
#
#         self.play(FadeIn(box), run_time=0.5)
#         self.play(
#             Create(p1),
#             run_time=3
#         )
#         self.play(Transform(p1, p2))
#         self.play(Transform(p2, p3))
#         self.play(Create(p4), run_time=10)
# Out:
# [12/18/23 20:07:14] INFO     Animation 0 : Using cached data (hash :                           ]8;id=2473;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=353287;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              1342159004_3974590055_223132457)
# [12/18/23 20:07:15] INFO     Animation 1 : Partial movie file written in                   ]8;id=820977;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=879378;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              720p30\partial_movie_files\ParticlesInABox\1353618911_4803990
#                              08_576923464.mp4'
# [12/18/23 20:07:16] INFO     Animation 2 : Partial movie file written in                   ]8;id=710941;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=611542;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              720p30\partial_movie_files\ParticlesInABox\1353618911_3087517
#                              468_4120168363.mp4'
#                     INFO     Animation 3 : Partial movie file written in                   ]8;id=481591;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=570520;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              720p30\partial_movie_files\ParticlesInABox\1353618911_2371781
#                              03_1873507957.mp4'
# [12/18/23 20:07:51] INFO     Animation 4 : Partial movie file written in                   ]8;id=351705;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=972309;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              720p30\partial_movie_files\ParticlesInABox\1353618911_7145683
#                              69_1089835709.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=817773;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=126749;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#607\607]8;;\
#                     INFO                                                                   ]8;id=422368;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=498395;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              720p30\ParticlesInABox.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=68785;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=744477;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#700\700]8;;\
#                              manim has removed the 4 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered ParticlesInABox                                                  ]8;id=902481;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=736746;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 5 animations
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-4dbe06729f37> in <module>
# ----> 1 get_ipython().run_cell_magic('manim', '-qm ParticlesInABox', '\nclass ParticlesInABox(Scene):\n    def construct(self):\n        size = 6\n        box = Rectangle(width=size, height=size)\n\n        def particle_updater(obj):\n            x_coord = obj.get_x()\n            y_coord = obj.get_y()\n\n            d1 = np.random.uniform(low=-0.04, high=0.04)\n            d2 = np.random.uniform(low=-0.03, high=0.03)\n            x_new = x_coord+d1 if (x_coord+d1 < 6) else x_coord-d1\n            y_new = y_coord+d2 if (y_coord+d2 < 6) else y_coord-d2\n            obj.move_to([x_new, y_new, 0])\n\n        def generate_particles(N, update=True, pos=[-2.4, 2.4]):\n            particles = VGroup()\n            for i in range(N):\n                # generate dot with random color\n                rand = lambda: np.random.uniform(low=0.0, high=1.0)\n                color = rgb_to_color([rand(), rand(), rand()])\n\n                dot = Dot(color=color).scale(.5)\n\n                # random position to dot\n                loc = np.array(\n                    [\n                        np.random.uniform(low=pos[0], high=pos[1]),\n                        np.random.uniform(low=pos[0], high=pos[1]),\n                        0\n                    ]\n                )\n\n                dot.move_to(loc)\n                \n                if update:\n                    dot.add_updater(particle_updater)\n                particles += dot\n\n            return particles\n\n        p1 = generate_particles(1, pos=[-.02, .02])\n        p2 = generate_particles(2, pos=[-.04, .04])\n        p3 = generate_particles(10, pos=[-.2, .2])\n        p4 = generate_particles(350)\n\n        self.play(FadeIn(box), run_time=0.5)\n        self.play(\n            Create(p1),\n            run_time=3\n        )\n        self.play(Transform(p1, p2))\n        self.play(Transform(p2, p3))\n        self.play(Create(p4), run_time=10)\n')
#
# c:\Users\Zach\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2360             with self.builtin_trap:
#    2361                 args = (magic_arg_s, cell)
# -> 2362                 result = fn(*args, **kwargs)
#    2363             return result
#    2364
#
# c:\Users\Zach\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# c:\Users\Zach\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\ipython_magic.py in manim(self, line, cell, local_ns)
#     189                         tmpfile,
#     190                         html_attributes=f'controls autoplay loop style="max-width: {config["media_width"]};"',
# --> 191                         embed=embed,
#     192                     )
#     193
#
# TypeError: __init__() got an unexpected keyword argument 'html_attributes'

# %%
# %%manim -ql -v WARNING MicrostateEOM
#
# class MicrostateEOM(Scene):
#     def construct(self):
#         # tex package
#         myTemplate = TexTemplate()
#         myTemplate.add_to_preamble(r"\usepackage{braket}")
#
#         # wavefunction strings
#         index = ValueTracker(10)
#         f1 = r"\hat{H} \ket{\psi(r_1)} = E \ket{\psi(r_1)}"
#         f2 = r"\hat{H} \ket{\psi(r_1, r_2)} = E \ket{\psi(r_1, r_2)}"
#         f3 = r"\hat{H} \ket{\psi(r_1, r_2, r_3)} = E \ket{\psi(r_1, r_2, r_3)}"
#         #fn = r"\hat{H} \ket{\psi(r_1, r_2, r_3, ...r_{:.1f})} = E \ket{\psi(r_1, r_2, r_3)}".format(index.get_value())
#
#         wf1 = MathTex(
#             f1,
#             tex_template=myTemplate
#         )
#         wf2 = MathTex(
#             f2,
#             tex_template=myTemplate
#         )
#         wf3 = MathTex(
#             f3,
#             tex_template=myTemplate
#         )
#         wfn = always_redraw(lambda: MathTex(
#             r"\hat{{H}} \ket{{\psi(r_1, r_2, r_3, ..., r_{{{arg}}})}} = E \ket{{\psi(r_1, r_2, r_3, ..., r_{{{arg}}}}}".format(arg=int(index.get_value())),
#             tex_template=myTemplate
#         ))
#
#         self.play(Write(wf1))
#         self.play(TransformMatchingShapes(wf1, wf2))
#         self.play(TransformMatchingShapes(wf2, wf3))
#         self.play(TransformMatchingShapes(wf3, wfn))
#         self.play(index.animate.set_value(101), run_time=6)
# Out:
# [12/18/23 18:41:57] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{10})} = E      ]8;id=101314;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=975302;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{10}} to
#                              media\Tex\427f9ad69af82266.tex
# [12/18/23 18:41:58] INFO     Animation 0 : Using cached data (hash :                           ]8;id=154131;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=807442;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              1342159004_2324183206_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=823235;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=450128;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              1353618911_2750948111_2358810818)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=243407;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=639212;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              1353618911_2350040175_2358810818)
# [12/18/23 18:42:00] INFO     Animation 3 : Partial movie file written in                   ]8;id=42936;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=550268;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              720p30\partial_movie_files\MicrostateEOM\1353618911_82311215_
#                              2358810818.mp4'
# [12/18/23 18:42:37] INFO     Animation 4 : Partial movie file written in                   ]8;id=365723;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=193811;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              720p30\partial_movie_files\MicrostateEOM\1353618911_338764736
#                              _658577863.mp4'
# Animation 5: _MethodAnimation(ValueTracker):  10%|#         | 18/180 [00:03<00:35,  4.56it/s]
# [12/18/23 18:42:41] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{11})} = E      ]8;id=65701;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=713187;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{11}} to
#                              media\Tex\ef2c7550a0ee645e.tex
# Animation 5: _MethodAnimation(ValueTracker):  15%|#5        | 27/180 [00:06<00:36,  4.20it/s]
# [12/18/23 18:42:44] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{12})} = E      ]8;id=711693;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=686378;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{12}} to
#                              media\Tex\e993e36cab696c74.tex
# Animation 5: _MethodAnimation(ValueTracker):  18%|#8        | 33/180 [00:09<00:41,  3.54it/s]
# [12/18/23 18:42:46] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{13})} = E      ]8;id=14578;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=861290;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{13}} to
#                              media\Tex\22d0477f7e552be9.tex
# Animation 5: _MethodAnimation(ValueTracker):  21%|##1       | 38/180 [00:11<00:43,  3.24it/s]
# [12/18/23 18:42:49] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{14})} = E      ]8;id=258916;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=129163;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{14}} to
#                              media\Tex\03ddac95f3d939c8.tex
# Animation 5: _MethodAnimation(ValueTracker):  23%|##2       | 41/180 [00:13<00:56,  2.46it/s]
# [12/18/23 18:42:50] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{15})} = E      ]8;id=11491;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=685848;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{15}} to
#                              media\Tex\60d977766f41e1ad.tex
# Animation 5: _MethodAnimation(ValueTracker):  24%|##4       | 44/180 [00:14<00:58,  2.31it/s]
# [12/18/23 18:42:52] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{16})} = E      ]8;id=249453;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=208096;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{16}} to
#                              media\Tex\282846916c6c65a7.tex
# Animation 5: _MethodAnimation(ValueTracker):  26%|##6       | 47/180 [00:16<00:59,  2.24it/s]
# [12/18/23 18:42:54] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{17})} = E      ]8;id=938390;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=26183;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{17}} to
#                              media\Tex\55f97ccc6ae5f328.tex
# Animation 5: _MethodAnimation(ValueTracker):  28%|##7       | 50/180 [00:18<00:59,  2.19it/s]
# [12/18/23 18:42:55] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{18})} = E      ]8;id=237173;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=62289;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{18}} to
#                              media\Tex\710ad17e10854a82.tex
# Animation 5: _MethodAnimation(ValueTracker):  29%|##8       | 52/180 [00:19<01:13,  1.74it/s]
# [12/18/23 18:42:57] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{19})} = E      ]8;id=138204;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=756781;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{19}} to
#                              media\Tex\79ee775a07f4fc07.tex
# Animation 5: _MethodAnimation(ValueTracker):  30%|###       | 54/180 [00:21<01:17,  1.62it/s]
# [12/18/23 18:42:58] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{20})} = E      ]8;id=755500;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=446944;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{20}} to
#                              media\Tex\f85ac1cf523d0892.tex
# Animation 5: _MethodAnimation(ValueTracker):  31%|###1      | 56/180 [00:22<01:20,  1.54it/s]
# [12/18/23 18:43:00] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{21})} = E      ]8;id=877463;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=446201;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{21}} to
#                              media\Tex\0c73bb8238880193.tex
# Animation 5: _MethodAnimation(ValueTracker):  32%|###1      | 57/180 [00:24<01:45,  1.17it/s]
# [12/18/23 18:43:01] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{22})} = E      ]8;id=445285;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=759380;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{22}} to
#                              media\Tex\0c862bb4239b9e16.tex
# Animation 5: _MethodAnimation(ValueTracker):  33%|###2      | 59/180 [00:25<01:31,  1.32it/s]
# [12/18/23 18:43:03] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{23})} = E      ]8;id=857624;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=533601;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{23}} to
#                              media\Tex\ef39bc6d6c281987.tex
# Animation 5: _MethodAnimation(ValueTracker):  33%|###3      | 60/180 [00:26<01:47,  1.11it/s]
# [12/18/23 18:43:04] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{24})} = E      ]8;id=575707;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=275008;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{24}} to
#                              media\Tex\ec517515fe22f91c.tex
# Animation 5: _MethodAnimation(ValueTracker):  34%|###4      | 62/180 [00:28<01:31,  1.29it/s]
# [12/18/23 18:43:05] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{25})} = E      ]8;id=50372;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=677150;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{25}} to
#                              media\Tex\35ed5dba582401af.tex
# Animation 5: _MethodAnimation(ValueTracker):  35%|###5      | 63/180 [00:29<01:47,  1.09it/s]
# [12/18/23 18:43:07] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{26})} = E      ]8;id=994552;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=337519;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{26}} to
#                              media\Tex\ece7b8a36f424993.tex
# Animation 5: _MethodAnimation(ValueTracker):  36%|###6      | 65/180 [00:31<01:30,  1.27it/s]
# [12/18/23 18:43:08] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{27})} = E      ]8;id=149401;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=3798;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{27}} to
#                              media\Tex\07e2023c9173fcd6.tex
# Animation 5: _MethodAnimation(ValueTracker):  37%|###6      | 66/180 [00:32<01:45,  1.08it/s]
# [12/18/23 18:43:09] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{28})} = E      ]8;id=111704;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=952228;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{28}} to
#                              media\Tex\9f2ef3a383a9ab0f.tex
# Animation 5: _MethodAnimation(ValueTracker):  37%|###7      | 67/180 [00:33<01:55,  1.02s/it]
# [12/18/23 18:43:11] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{29})} = E      ]8;id=749492;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=841358;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{29}} to
#                              media\Tex\3ca4157a6afa9d38.tex
# Animation 5: _MethodAnimation(ValueTracker):  38%|###7      | 68/180 [00:34<02:06,  1.13s/it]
# [12/18/23 18:43:12] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{30})} = E      ]8;id=737906;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=706191;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{30}} to
#                              media\Tex\292a8a7c5bf0851b.tex
# Animation 5: _MethodAnimation(ValueTracker):  38%|###8      | 69/180 [00:36<02:09,  1.16s/it]
# [12/18/23 18:43:13] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{31})} = E      ]8;id=210836;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=822146;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{31}} to
#                              media\Tex\64899cd1380bb5e1.tex
# Animation 5: _MethodAnimation(ValueTracker):  39%|###8      | 70/180 [00:37<02:10,  1.19s/it]
# [12/18/23 18:43:15] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{32})} = E      ]8;id=456624;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=368440;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{32}} to
#                              media\Tex\dc1197c4f6fb1dc9.tex
# Animation 5: _MethodAnimation(ValueTracker):  39%|###9      | 71/180 [00:38<02:11,  1.21s/it]
# [12/18/23 18:43:16] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{33})} = E      ]8;id=510547;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=554215;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{33}} to
#                              media\Tex\5f20acd7db7294fa.tex
# Animation 5: _MethodAnimation(ValueTracker):  40%|####      | 72/180 [00:39<02:11,  1.22s/it]
# [12/18/23 18:43:17] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{34})} = E      ]8;id=532186;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=610264;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{34}} to
#                              media\Tex\d18eaf5ede0de173.tex
# Animation 5: _MethodAnimation(ValueTracker):  41%|####      | 73/180 [00:41<02:10,  1.22s/it]
# [12/18/23 18:43:18] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{35})} = E      ]8;id=431687;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=705598;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{35}} to
#                              media\Tex\2c8cb9580938d57c.tex
# Animation 5: _MethodAnimation(ValueTracker):  41%|####1     | 74/180 [00:42<02:14,  1.27s/it]
# [12/18/23 18:43:20] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{36})} = E      ]8;id=996507;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=652488;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{36}} to
#                              media\Tex\097d3648673986a0.tex
# Animation 5: _MethodAnimation(ValueTracker):  42%|####1     | 75/180 [00:43<02:11,  1.26s/it]
# [12/18/23 18:43:21] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{37})} = E      ]8;id=248988;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=328509;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{37}} to
#                              media\Tex\84aa904f671189c0.tex
# Animation 5: _MethodAnimation(ValueTracker):  42%|####2     | 76/180 [00:45<02:10,  1.26s/it]
# [12/18/23 18:43:22] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{38})} = E      ]8;id=325208;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=591060;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{38}} to
#                              media\Tex\5a557c2f0764e795.tex
# Animation 5: _MethodAnimation(ValueTracker):  43%|####2     | 77/180 [00:46<02:09,  1.26s/it]
# [12/18/23 18:43:23] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{39})} = E      ]8;id=128767;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=811499;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{39}} to
#                              media\Tex\3cb0384649f7b789.tex
# Animation 5: _MethodAnimation(ValueTracker):  43%|####3     | 78/180 [00:47<02:08,  1.26s/it]
# [12/18/23 18:43:25] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{40})} = E      ]8;id=970463;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=441016;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{40}} to
#                              media\Tex\5f5fc220e00013dc.tex
# Animation 5: _MethodAnimation(ValueTracker):  44%|####3     | 79/180 [00:48<02:10,  1.29s/it]
# [12/18/23 18:43:26] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{41})} = E      ]8;id=948994;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=127696;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{41}} to
#                              media\Tex\057c503f26cf1767.tex
# Animation 5: _MethodAnimation(ValueTracker):  44%|####4     | 80/180 [00:50<02:07,  1.28s/it]
# [12/18/23 18:43:27] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{43})} = E      ]8;id=236532;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=866637;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{43}} to
#                              media\Tex\3986ab5404e9e51d.tex
# Animation 5: _MethodAnimation(ValueTracker):  45%|####5     | 81/180 [00:51<02:05,  1.27s/it]
# [12/18/23 18:43:29] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{44})} = E      ]8;id=119723;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=121263;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{44}} to
#                              media\Tex\5e08fafaad2e8af5.tex
# Animation 5: _MethodAnimation(ValueTracker):  46%|####5     | 82/180 [00:52<02:04,  1.27s/it]
# [12/18/23 18:43:30] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{45})} = E      ]8;id=212860;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=210283;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{45}} to
#                              media\Tex\a570f2385aa8e807.tex
# Animation 5: _MethodAnimation(ValueTracker):  46%|####6     | 83/180 [00:54<02:08,  1.32s/it]
# [12/18/23 18:43:31] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{46})} = E      ]8;id=551763;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=309915;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{46}} to
#                              media\Tex\86e49f83ee5d3db1.tex
# Animation 5: _MethodAnimation(ValueTracker):  47%|####6     | 84/180 [00:55<02:06,  1.31s/it]
# [12/18/23 18:43:33] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{47})} = E      ]8;id=341442;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=291882;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{47}} to
#                              media\Tex\a3c4ee352cd7bdcc.tex
# Animation 5: _MethodAnimation(ValueTracker):  47%|####7     | 85/180 [00:56<02:04,  1.31s/it]
# [12/18/23 18:43:34] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{49})} = E      ]8;id=548895;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=340869;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{49}} to
#                              media\Tex\186018ded8977240.tex
# Animation 5: _MethodAnimation(ValueTracker):  48%|####7     | 86/180 [00:58<02:06,  1.34s/it]
# [12/18/23 18:43:35] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{50})} = E      ]8;id=470351;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=119480;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{50}} to
#                              media\Tex\4a2b667e023470a2.tex
# Animation 5: _MethodAnimation(ValueTracker):  48%|####8     | 87/180 [00:59<02:06,  1.36s/it]
# [12/18/23 18:43:37] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{51})} = E      ]8;id=476862;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=669601;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{51}} to
#                              media\Tex\691627072c07d67e.tex
# Animation 5: _MethodAnimation(ValueTracker):  49%|####8     | 88/180 [01:00<02:04,  1.36s/it]
# [12/18/23 18:43:38] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{52})} = E      ]8;id=980073;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=51887;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{52}} to
#                              media\Tex\894b59a21c904de7.tex
# Animation 5: _MethodAnimation(ValueTracker):  49%|####9     | 89/180 [01:02<02:00,  1.32s/it]
# [12/18/23 18:43:39] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{54})} = E      ]8;id=33181;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=390675;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{54}} to
#                              media\Tex\f20a3c1fc9a388bb.tex
# Animation 5: _MethodAnimation(ValueTracker):  50%|#####     | 90/180 [01:03<01:56,  1.30s/it]
# [12/18/23 18:43:41] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{55})} = E      ]8;id=216578;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=93441;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{55}} to
#                              media\Tex\c030f3fb7d01482e.tex
# Animation 5: _MethodAnimation(ValueTracker):  51%|#####     | 91/180 [01:04<01:53,  1.28s/it]
# [12/18/23 18:43:42] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{56})} = E      ]8;id=120320;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=539335;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{56}} to
#                              media\Tex\ea8c15613b8c4086.tex
# Animation 5: _MethodAnimation(ValueTracker):  51%|#####1    | 92/180 [01:05<01:51,  1.27s/it]
# [12/18/23 18:43:43] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{58})} = E      ]8;id=437585;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=201239;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{58}} to
#                              media\Tex\5608ff09aaf0a930.tex
# Animation 5: _MethodAnimation(ValueTracker):  52%|#####1    | 93/180 [01:07<01:49,  1.26s/it]
# [12/18/23 18:43:44] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{59})} = E      ]8;id=956849;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=859126;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{59}} to
#                              media\Tex\1a348bf5409bfc07.tex
# Animation 5: _MethodAnimation(ValueTracker):  52%|#####2    | 94/180 [01:08<01:47,  1.25s/it]
# [12/18/23 18:43:46] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{60})} = E      ]8;id=180399;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=80628;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{60}} to
#                              media\Tex\28dd59f65d61467d.tex
# Animation 5: _MethodAnimation(ValueTracker):  53%|#####2    | 95/180 [01:09<01:49,  1.29s/it]
# [12/18/23 18:43:47] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{61})} = E      ]8;id=688300;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=613341;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{61}} to
#                              media\Tex\6fac38463b7c0594.tex
# Animation 5: _MethodAnimation(ValueTracker):  53%|#####3    | 96/180 [01:10<01:47,  1.27s/it]
# [12/18/23 18:43:48] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{63})} = E      ]8;id=806533;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=730053;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{63}} to
#                              media\Tex\d5e83ab9889540bf.tex
# Animation 5: _MethodAnimation(ValueTracker):  54%|#####3    | 97/180 [01:12<01:45,  1.27s/it]
# [12/18/23 18:43:49] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{64})} = E      ]8;id=360494;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=896787;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{64}} to
#                              media\Tex\d2c07c1ae2184b0c.tex
# Animation 5: _MethodAnimation(ValueTracker):  54%|#####4    | 98/180 [01:13<01:43,  1.27s/it]
# [12/18/23 18:43:51] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{65})} = E      ]8;id=883983;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=529218;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{65}} to
#                              media\Tex\b8d16c325f8e860d.tex
# Animation 5: _MethodAnimation(ValueTracker):  55%|#####5    | 99/180 [01:14<01:42,  1.26s/it]
# [12/18/23 18:43:52] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{66})} = E      ]8;id=589537;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=184271;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{66}} to
#                              media\Tex\cd38635af05b1ae4.tex
# Animation 5: _MethodAnimation(ValueTracker):  56%|#####5    | 100/180 [01:15<01:40,  1.26s/it]
# [12/18/23 18:43:53] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{67})} = E      ]8;id=7200;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=680105;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{67}} to
#                              media\Tex\a671ad1313afee63.tex
# Animation 5: _MethodAnimation(ValueTracker):  56%|#####6    | 101/180 [01:17<01:39,  1.26s/it]
# [12/18/23 18:43:54] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{69})} = E      ]8;id=452814;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=186492;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{69}} to
#                              media\Tex\d64d88c94a8377bf.tex
# Animation 5: _MethodAnimation(ValueTracker):  57%|#####6    | 102/180 [01:18<01:38,  1.26s/it]
# [12/18/23 18:43:56] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{70})} = E      ]8;id=312399;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=181226;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{70}} to
#                              media\Tex\bbf0cc1ac381a733.tex
# Animation 5: _MethodAnimation(ValueTracker):  57%|#####7    | 103/180 [01:19<01:36,  1.26s/it]
# [12/18/23 18:43:57] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{71})} = E      ]8;id=692427;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=298205;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{71}} to
#                              media\Tex\71eaa8ec609c7ab6.tex
# Animation 5: _MethodAnimation(ValueTracker):  58%|#####7    | 104/180 [01:21<01:37,  1.29s/it]
# [12/18/23 18:43:58] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{72})} = E      ]8;id=892069;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=958387;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{72}} to
#                              media\Tex\9be97665b77f4f64.tex
# Animation 5: _MethodAnimation(ValueTracker):  58%|#####8    | 105/180 [01:22<01:35,  1.28s/it]
# [12/18/23 18:44:00] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{73})} = E      ]8;id=226022;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=651893;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{73}} to
#                              media\Tex\310ee1fb51ca8e28.tex
# Animation 5: _MethodAnimation(ValueTracker):  59%|#####8    | 106/180 [01:23<01:33,  1.27s/it]
# [12/18/23 18:44:01] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{74})} = E      ]8;id=817299;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=752544;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{74}} to
#                              media\Tex\928544e11aed2c50.tex
# Animation 5: _MethodAnimation(ValueTracker):  59%|#####9    | 107/180 [01:24<01:31,  1.26s/it]
# [12/18/23 18:44:02] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{75})} = E      ]8;id=10447;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=362044;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{75}} to
#                              media\Tex\6dad239aed125958.tex
# Animation 5: _MethodAnimation(ValueTracker):  60%|######    | 108/180 [01:26<01:31,  1.27s/it]
# [12/18/23 18:44:03] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{76})} = E      ]8;id=780081;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=822586;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{76}} to
#                              media\Tex\f2da963ef53e7148.tex
# Animation 5: _MethodAnimation(ValueTracker):  61%|######    | 109/180 [01:27<01:30,  1.27s/it]
# [12/18/23 18:44:05] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{77})} = E      ]8;id=154645;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=95686;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{77}} to
#                              media\Tex\61959c0fbe8283f5.tex
# Animation 5: _MethodAnimation(ValueTracker):  61%|######1   | 110/180 [01:28<01:28,  1.26s/it]
# [12/18/23 18:44:06] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{78})} = E      ]8;id=282264;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=386927;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{78}} to
#                              media\Tex\c3633f5e2f182c83.tex
# Animation 5: _MethodAnimation(ValueTracker):  62%|######1   | 111/180 [01:29<01:27,  1.27s/it]
# [12/18/23 18:44:07] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{79})} = E      ]8;id=601803;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=872476;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{79}} to
#                              media\Tex\9ea06b033e776d4d.tex
# Animation 5: _MethodAnimation(ValueTracker):  62%|######2   | 112/180 [01:31<01:25,  1.26s/it]
# [12/18/23 18:44:08] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{80})} = E      ]8;id=627387;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=130310;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{80}} to
#                              media\Tex\8c2c6643d8987191.tex
# Animation 5: _MethodAnimation(ValueTracker):  63%|######2   | 113/180 [01:32<01:24,  1.26s/it]
# [12/18/23 18:44:10] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{81})} = E      ]8;id=254575;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=739371;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{81}} to
#                              media\Tex\7db973d6c6b8c77d.tex
# Animation 5: _MethodAnimation(ValueTracker):  63%|######3   | 114/180 [01:33<01:23,  1.26s/it]
# [12/18/23 18:44:11] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{82})} = E      ]8;id=919167;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=258014;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{82}} to
#                              media\Tex\710fff179257e04d.tex
# Animation 5: _MethodAnimation(ValueTracker):  64%|######3   | 115/180 [01:34<01:21,  1.25s/it]
# [12/18/23 18:44:12] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{83})} = E      ]8;id=68333;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=140279;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{83}} to
#                              media\Tex\0cc37aad1f33ffe7.tex
# Animation 5: _MethodAnimation(ValueTracker):  64%|######4   | 116/180 [01:36<01:19,  1.25s/it]
# [12/18/23 18:44:13] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{84})} = E      ]8;id=315750;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=4699;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{84}} to
#                              media\Tex\2a441030ef699158.tex
# Animation 5: _MethodAnimation(ValueTracker):  66%|######5   | 118/180 [01:37<00:59,  1.04it/s]
# [12/18/23 18:44:15] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{85})} = E      ]8;id=404731;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=605794;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{85}} to
#                              media\Tex\5fed3b40fc3bb2b6.tex
# Animation 5: _MethodAnimation(ValueTracker):  66%|######6   | 119/180 [01:38<01:04,  1.05s/it]
# [12/18/23 18:44:16] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{86})} = E      ]8;id=298163;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=928454;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{86}} to
#                              media\Tex\53c1fc1d135b5948.tex
# Animation 5: _MethodAnimation(ValueTracker):  67%|######7   | 121/180 [01:40<00:50,  1.17it/s]
# [12/18/23 18:44:18] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{87})} = E      ]8;id=867039;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=662931;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{87}} to
#                              media\Tex\00f5afb2ac843e9f.tex
# Animation 5: _MethodAnimation(ValueTracker):  68%|######7   | 122/180 [01:41<00:57,  1.01it/s]
# [12/18/23 18:44:19] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{88})} = E      ]8;id=606556;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=571847;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{88}} to
#                              media\Tex\d943d138cf5397f7.tex
# Animation 5: _MethodAnimation(ValueTracker):  69%|######8   | 124/180 [01:43<00:46,  1.20it/s]
# [12/18/23 18:44:21] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{89})} = E      ]8;id=416244;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=28796;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{89}} to
#                              media\Tex\99a3f30e244e1ec3.tex
# Animation 5: _MethodAnimation(ValueTracker):  69%|######9   | 125/180 [01:44<00:52,  1.05it/s]
# [12/18/23 18:44:22] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{90})} = E      ]8;id=359343;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=7046;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{90}} to
#                              media\Tex\f43d81fd5f9c1c14.tex
# Animation 5: _MethodAnimation(ValueTracker):  71%|#######   | 127/180 [01:46<00:42,  1.23it/s]
# [12/18/23 18:44:23] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{91})} = E      ]8;id=50348;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=437565;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{91}} to
#                              media\Tex\2ebad0e1bc8fd7a6.tex
# Animation 5: _MethodAnimation(ValueTracker):  72%|#######1  | 129/180 [01:47<00:37,  1.35it/s]
# [12/18/23 18:44:25] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{92})} = E      ]8;id=915172;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=957039;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{92}} to
#                              media\Tex\730d8317485603ba.tex
# Animation 5: _MethodAnimation(ValueTracker):  73%|#######2  | 131/180 [01:49<00:34,  1.43it/s]
# [12/18/23 18:44:26] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{93})} = E      ]8;id=35900;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=837156;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{93}} to
#                              media\Tex\67e89e5642fed79b.tex
# Animation 5: _MethodAnimation(ValueTracker):  74%|#######4  | 134/180 [01:50<00:25,  1.80it/s]
# [12/18/23 18:44:28] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{94})} = E      ]8;id=326407;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=147832;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{94}} to
#                              media\Tex\a4d7fa149091d44b.tex
# Animation 5: _MethodAnimation(ValueTracker):  76%|#######6  | 137/180 [01:52<00:22,  1.93it/s]
# [12/18/23 18:44:30] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{95})} = E      ]8;id=705554;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=536547;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{95}} to
#                              media\Tex\5e83e3bc0cdc4eb9.tex
# Animation 5: _MethodAnimation(ValueTracker):  78%|#######7  | 140/180 [01:54<00:20,  1.96it/s]
# [12/18/23 18:44:32] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{96})} = E      ]8;id=839723;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=446085;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{96}} to
#                              media\Tex\9a8a100ee40d65db.tex
# Animation 5: _MethodAnimation(ValueTracker):  79%|#######9  | 143/180 [01:56<00:18,  2.01it/s]
# [12/18/23 18:44:34] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{97})} = E      ]8;id=596380;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=7408;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{97}} to
#                              media\Tex\48299973104b4722.tex
# Animation 5: _MethodAnimation(ValueTracker):  82%|########2 | 148/180 [01:58<00:12,  2.66it/s]
# [12/18/23 18:44:36] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{98})} = E      ]8;id=228267;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=704819;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{98}} to
#                              media\Tex\83cf24b58ad0628e.tex
# Animation 5: _MethodAnimation(ValueTracker):  86%|########5 | 154/180 [02:01<00:08,  3.04it/s]
# [12/18/23 18:44:38] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{99})} = E      ]8;id=383466;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=478499;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{99}} to
#                              media\Tex\8ffa9599bdb5d5e0.tex
# Animation 5: _MethodAnimation(ValueTracker):  91%|######### | 163/180 [02:04<00:04,  3.54it/s]
# [12/18/23 18:44:42] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{100})} = E     ]8;id=259183;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=367686;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{100}} to
#                              media\Tex\40277032d4aa7e42.tex
# [12/18/23 18:44:51] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{101})} = E     ]8;id=125809;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=439680;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{101}} to
#                              media\Tex\16f4e57913f176d5.tex
# [12/18/23 18:44:53] INFO     Animation 5 : Partial movie file written in                   ]8;id=821883;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=644965;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              720p30\partial_movie_files\MicrostateEOM\1353618911_361144460
#                              5_505058938.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=794338;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=404540;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#607\607]8;;\
#                     INFO                                                                   ]8;id=203890;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=666807;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              720p30\MicrostateEOM.mp4'
#                     INFO     Rendered MicrostateEOM                                                    ]8;id=79616;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=598967;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 6 animations
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-6946b14b88ec> in <module>
# ----> 1 get_ipython().run_cell_magic('manim', '-qm MicrostateEOM', '\nclass MicrostateEOM(Scene):\n    def construct(self):\n        # tex package\n        myTemplate = TexTemplate()\n        myTemplate.add_to_preamble(r"\\usepackage{braket}")\n\n        # wavefunction strings\n        index = ValueTracker(10)\n        f1 = r"\\hat{H} \\ket{\\psi(r_1)} = E \\ket{\\psi(r_1)}"\n        f2 = r"\\hat{H} \\ket{\\psi(r_1, r_2)} = E \\ket{\\psi(r_1, r_2)}"\n        f3 = r"\\hat{H} \\ket{\\psi(r_1, r_2, r_3)} = E \\ket{\\psi(r_1, r_2, r_3)}"\n        #fn = r"\\hat{H} \\ket{\\psi(r_1, r_2, r_3, ...r_{:.1f})} = E \\ket{\\psi(r_1, r_2, r_3)}".format(index.get_value())\n\n        wf1 = MathTex(\n            f1,\n            tex_template=myTemplate\n        )\n        wf2 = MathTex(\n            f2,\n            tex_template=myTemplate\n        )\n        wf3 = MathTex(\n            f3,\n            tex_template=myTemplate\n        )\n        wfn = always_redraw(lambda: MathTex(\n            r"\\hat{{H}} \\ket{{\\psi(r_1, r_2, r_3, ..., r_{{{arg}}})}} = E \\ket{{\\psi(r_1, r_2, r_3, ..., r_{{{arg}}}}}".format(arg=int(index.get_value())),\n            tex_template=myTemplate\n        ))\n\n        # add arguments for other particles\n        # def arg_updater(mob):\n        #     mob.become(\n        #         MathTex(\n        #             function,\n        #             tex_template=myTemplate\n        #         )\n        #     )\n\n        #wfn.add_updater(arg_updater)\n\n        self.play(Write(wf1))\n        self.play(TransformMatchingShapes(wf1, wf2))\n        self.play(TransformMatchingShapes(wf2, wf3))\n        self.play(TransformMatchingShapes(wf3, wfn))\n        self.play(Write(wfn))\n        self.play(index.animate.set_value(101), run_time=6)\n')
#
# c:\Users\Zach\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2360             with self.builtin_trap:
#    2361                 args = (magic_arg_s, cell)
# -> 2362                 result = fn(*args, **kwargs)
#    2363             return result
#    2364
#
# c:\Users\Zach\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# c:\Users\Zach\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\ipython_magic.py in manim(self, line, cell, local_ns)
#     189                         tmpfile,
#     190                         html_attributes=f'controls autoplay loop style="max-width: {config["media_width"]};"',
# --> 191                         embed=embed,
#     192                     )
#     193
#
# TypeError: __init__() got an unexpected keyword argument 'html_attributes'

# %%
# %%manim -qh -r 1080,1920 IntroScene
#
# class IntroScene(Scene):
#     def construct(self):
#         # PARTICLES IN A BOX
#         size = 6.5
#         box = Rectangle(width=size, height=size)
#
#         def particle_updater(obj):
#             x_coord = obj.get_x()
#             y_coord = obj.get_y()
#
#             d1 = np.random.uniform(low=-0.04, high=0.04)
#             d2 = np.random.uniform(low=-0.03, high=0.03)
#
#             # new coords
#             x_new = x_coord+d1
#             y_new = y_coord+d2
#             if x_coord+d1 > 6:
#                 x_new = x_coord-d1
#             elif x_coord+d1 < -6:
#                 x_new = x_coord-d1
#
#             if y_coord+d2 > 6:
#                 y_new = y_coord-d2
#             elif y_coord+d2 < -6:
#                 y_new = y_coord-d2
#
#             #x_new = x_coord+d1 if (x_coord+d1 < 6) else x_coord-d1
#             #y_new = y_coord+d2 if (y_coord+d2 < 6) else y_coord-d2
#             obj.move_to([x_new, y_new, 0])
#
#         def generate_particles(N, update=True, pos=[-2.4, 2.4]):
#             particles = VGroup()
#             for i in range(N):
#                 # generate dot with random color
#                 rand = lambda: np.random.uniform(low=0.0, high=1.0)
#                 color = rgb_to_color([rand(), rand(), rand()])
#
#                 dot = Dot(color=color).scale(.5)
#
#                 # random position to dot
#                 loc = np.array(
#                     [
#                         np.random.uniform(low=pos[0], high=pos[1]),
#                         np.random.uniform(low=pos[0], high=pos[1]),
#                         0
#                     ]
#                 )
#
#                 dot.move_to(loc)
#
#                 if update:
#                     dot.add_updater(particle_updater)
#                 particles += dot
#
#             return particles
#
#         p1 = generate_particles(1, pos=[-.02, .02])
#         p2 = generate_particles(2, pos=[-.04, .04])
#         p3 = generate_particles(3, pos=[-.2, .2])
#         p4 = generate_particles(10, pos=[-.2, .2])
#         p5 = generate_particles(350)
#
#         # LATEX EOM
#         # tex package
#         myTemplate = TexTemplate()
#         myTemplate.add_to_preamble(r"\usepackage{braket}")
#
#         # wavefunction strings
#         index = ValueTracker(10)
#         f1 = r"\hat{H} \ket{\psi(r_1)} = E \ket{\psi(r_1)}"
#         f2 = r"\hat{H} \ket{\psi(r_1, r_2)} = E \ket{\psi(r_1, r_2)}"
#         f3 = r"\hat{H} \ket{\psi(r_1, r_2, r_3)} = E \ket{\psi(r_1, r_2, r_3)}"
#         f4 = r"\hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{10})} = E \ket{\psi(r_1, r_2, r_3, ..., r_{10})}"
#
#         wf1 = MathTex(
#             f1,
#             tex_template=myTemplate
#         ).next_to(box, UP)
#         wf2 = MathTex(
#             f2,
#             tex_template=myTemplate
#         ).next_to(box, UP)
#         wf3 = MathTex(
#             f3,
#             tex_template=myTemplate
#         ).next_to(box, UP)
#         wf4 = MathTex(
#             f4,
#             tex_template=myTemplate
#         ).next_to(box, UP)
#         wfn = always_redraw(lambda: MathTex(
#             r"\hat{{H}} \ket{{\psi(r_1, r_2, r_3, ..., r_{{{arg}}})}} = E \ket{{\psi(r_1, r_2, r_3, ..., r_{{{arg}}})}}".format(arg=int(index.get_value())),
#             tex_template=myTemplate
#         ).next_to(box, UP))
#
#         # SCENE
#         animations = [
#             (Transform(p4, p5, run_time=12)),
#             index.animate.set_value(101)
#         ]
#
#         self.play(FadeIn(box), run_time=0.5)
#         self.play(
#             Create(p1),
#             run_time=3
#         )
#         self.play(Write(wf1))
#         self.play(
#             Transform(p1, p2),
#             TransformMatchingShapes(wf1, wf2),
#             run_time=2
#             )
#         self.play(
#             Transform(p2, p3),
#             TransformMatchingShapes(wf2, wf3),
#             run_time=2
#         )
#         self.play(
#             Transform(p3, p4),
#             TransformMatchingShapes(wf3,wfn),
#             run_time=3
#         )
#         self.play(*animations, lag_ratio=2, run_time=10)
#
#         self.play(
#             Unwrite(wfn),
#             Unwrite(p4),
#             Unwrite(box)
#         )
#
#         self.wait(2)
# Out:
# [12/28/23 15:53:58] INFO     Writing \hat{H} \ket{\psi(r_1)} = E \ket{\psi(r_1)} to          ]8;id=547701;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=315500;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              media\Tex\3ce4813330aafab1.tex
# [12/28/23 15:53:59] INFO     Writing \hat{H} \ket{\psi(r_1, r_2)} = E \ket{\psi(r_1, r_2)}   ]8;id=231250;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=805719;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              to media\Tex\7664d90367743002.tex
# [12/28/23 15:54:01] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3)} = E \ket{\psi(r_1,    ]8;id=759597;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=453506;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              r_2, r_3)} to media\Tex\6dda0b757c3b22bc.tex
# [12/28/23 15:54:02] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{10})} = E      ]8;id=731178;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=455449;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{10})} to
#                              media\Tex\d6c987015f2aa86a.tex
# [12/28/23 15:54:05] INFO     Animation 0 : Partial movie file written in                   ]8;id=706977;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=248410;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\partial_movie_files\IntroScene\4222611999_3719276276_
#                              223132457.mp4'
# [12/28/23 15:54:08] INFO     Animation 1 : Partial movie file written in                   ]8;id=806684;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=396620;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\partial_movie_files\IntroScene\4245490092_1339499212_
#                              788456480.mp4'
# [12/28/23 15:54:11] INFO     Animation 2 : Partial movie file written in                   ]8;id=647689;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=581212;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\partial_movie_files\IntroScene\4245490092_801870779_2
#                              99196186.mp4'
# [12/28/23 15:54:14] INFO     Animation 3 : Partial movie file written in                   ]8;id=236960;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=88467;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\partial_movie_files\IntroScene\4245490092_2467253614_
#                              1403167523.mp4'
# [12/28/23 15:54:17] INFO     Animation 4 : Partial movie file written in                   ]8;id=782390;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=764553;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\partial_movie_files\IntroScene\4245490092_2576602771_
#                              2642742235.mp4'
# [12/28/23 15:54:24] INFO     Animation 5 : Partial movie file written in                   ]8;id=92235;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=523986;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\partial_movie_files\IntroScene\4245490092_2870109881_
#                              768434529.mp4'
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  10%|9         | 59/600 [00:27<04:10,  2.16it/s]
# [12/28/23 15:54:52] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{11})} = E      ]8;id=703323;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=633304;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{11})} to
#                              media\Tex\e797b774924bb447.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  15%|#4        | 88/600 [00:41<03:53,  2.19it/s]
# [12/28/23 15:55:06] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{12})} = E      ]8;id=364685;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=300183;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{12})} to
#                              media\Tex\ad589941ee24000d.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  18%|#8        | 109/600 [00:52<04:05,  2.00it/s]
# [12/28/23 15:55:18] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{13})} = E      ]8;id=120376;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=22211;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{13})} to
#                              media\Tex\ede292611208bd8a.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  21%|##        | 124/600 [01:01<03:53,  2.04it/s]
# [12/28/23 15:55:26] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{14})} = E      ]8;id=300217;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=811460;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{14})} to
#                              media\Tex\1c097bb5677f0693.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  23%|##2       | 136/600 [01:09<04:42,  1.64it/s]
# [12/28/23 15:55:34] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{15})} = E      ]8;id=303915;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=405207;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{15})} to
#                              media\Tex\6247a8ae06828538.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  24%|##4       | 147/600 [01:17<04:18,  1.75it/s]
# [12/28/23 15:55:42] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{16})} = E      ]8;id=644175;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=312213;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{16})} to
#                              media\Tex\5e18d05b8e7344f6.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  26%|##6       | 156/600 [01:25<05:34,  1.33it/s]
# [12/28/23 15:55:50] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{17})} = E      ]8;id=70494;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=832883;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{17})} to
#                              media\Tex\81b5944f17bfdcf6.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  27%|##7       | 164/600 [01:31<04:30,  1.61it/s]
# [12/28/23 15:55:56] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{18})} = E      ]8;id=870366;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=835602;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{18})} to
#                              media\Tex\976289ea210445b0.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  28%|##8       | 171/600 [01:37<05:00,  1.43it/s]
# [12/28/23 15:56:02] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{19})} = E      ]8;id=580110;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=893244;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{19})} to
#                              media\Tex\8e8ae08fd3527ed4.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  30%|##9       | 178/600 [01:42<04:06,  1.71it/s]
# [12/28/23 15:56:07] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{20})} = E      ]8;id=660013;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=86422;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{20})} to
#                              media\Tex\b4986d36bb9e74f9.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  31%|###       | 184/600 [01:46<04:16,  1.62it/s]
# [12/28/23 15:56:11] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{21})} = E      ]8;id=9723;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=617696;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{21})} to
#                              media\Tex\3240c6c08d854487.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  32%|###1      | 190/600 [01:51<04:16,  1.60it/s]
# [12/28/23 15:56:16] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{22})} = E      ]8;id=49775;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=836245;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{22})} to
#                              media\Tex\a081323f63a1bf7b.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  32%|###2      | 195/600 [01:55<04:21,  1.55it/s]
# [12/28/23 15:56:20] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{23})} = E      ]8;id=770789;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=54478;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{23})} to
#                              media\Tex\00e2373f24d7793b.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  33%|###3      | 200/600 [01:59<04:33,  1.46it/s]
# [12/28/23 15:56:24] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{24})} = E      ]8;id=975109;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=465664;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{24})} to
#                              media\Tex\426eafeb0159cfcb.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  34%|###4      | 205/600 [02:03<04:24,  1.49it/s]
# [12/28/23 15:56:28] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{25})} = E      ]8;id=79690;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=718028;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{25})} to
#                              media\Tex\9f8bfe953ac89063.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  35%|###5      | 210/600 [02:07<04:04,  1.60it/s]
# [12/28/23 15:56:32] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{26})} = E      ]8;id=417982;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=148563;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{26})} to
#                              media\Tex\8160c04ae81bee12.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  36%|###5      | 214/600 [02:10<04:24,  1.46it/s]
# [12/28/23 15:56:35] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{27})} = E      ]8;id=208885;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=540556;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{27})} to
#                              media\Tex\143d0656927d5221.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  36%|###6      | 218/600 [02:14<04:22,  1.45it/s]
# [12/28/23 15:56:39] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{28})} = E      ]8;id=270548;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=859352;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{28})} to
#                              media\Tex\543a018a36defe06.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  37%|###7      | 222/600 [02:17<04:32,  1.39it/s]
# [12/28/23 15:56:42] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{29})} = E      ]8;id=402896;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=828941;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{29})} to
#                              media\Tex\414ff69e5b19223e.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  38%|###7      | 226/600 [02:21<04:44,  1.32it/s]
# [12/28/23 15:56:46] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{30})} = E      ]8;id=277927;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=47125;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{30})} to
#                              media\Tex\e4492553ffee6906.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  38%|###8      | 229/600 [02:24<05:08,  1.20it/s]
# [12/28/23 15:56:49] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{31})} = E      ]8;id=916187;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=31055;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{31})} to
#                              media\Tex\341fa4b0aaa89408.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  39%|###8      | 233/600 [02:27<04:38,  1.32it/s]
# [12/28/23 15:56:52] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{32})} = E      ]8;id=983286;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=312403;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{32})} to
#                              media\Tex\b3123883799e7ed6.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  40%|###9      | 237/600 [02:31<04:47,  1.26it/s]
# [12/28/23 15:56:56] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{33})} = E      ]8;id=542157;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=318958;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{33})} to
#                              media\Tex\afbc8670686878cf.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  40%|####      | 240/600 [02:34<04:50,  1.24it/s]
# [12/28/23 15:56:59] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{34})} = E      ]8;id=900485;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=937334;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{34})} to
#                              media\Tex\a10a9b5db5300c55.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  40%|####      | 243/600 [02:37<05:08,  1.16it/s]
# [12/28/23 15:57:02] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{35})} = E      ]8;id=336223;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=251905;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{35})} to
#                              media\Tex\49d60e3f0c6c6431.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  41%|####1     | 246/600 [02:40<05:07,  1.15it/s]
# [12/28/23 15:57:05] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{36})} = E      ]8;id=439002;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=513879;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{36})} to
#                              media\Tex\7dca38800190a3c7.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  42%|####1     | 249/600 [02:43<05:10,  1.13it/s]
# [12/28/23 15:57:08] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{37})} = E      ]8;id=59357;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=571132;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{37})} to
#                              media\Tex\42b869065349ce76.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  42%|####2     | 253/600 [02:47<04:18,  1.34it/s]
# [12/28/23 15:57:12] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{38})} = E      ]8;id=419997;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=597301;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{38})} to
#                              media\Tex\0c87775cf714ef99.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  43%|####2     | 256/600 [02:49<04:31,  1.27it/s]
# [12/28/23 15:57:14] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{39})} = E      ]8;id=770023;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=72500;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{39})} to
#                              media\Tex\12a2e83773a32a2a.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  43%|####3     | 259/600 [02:52<04:27,  1.27it/s]
# [12/28/23 15:57:17] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{40})} = E      ]8;id=985149;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=666965;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{40})} to
#                              media\Tex\9a0158f564cd190c.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  44%|####3     | 261/600 [02:54<05:00,  1.13it/s]
# [12/28/23 15:57:19] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{41})} = E      ]8;id=674174;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=691307;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{41})} to
#                              media\Tex\f4aef135826759d1.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  44%|####4     | 264/600 [02:57<04:35,  1.22it/s]
# [12/28/23 15:57:22] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{42})} = E      ]8;id=372469;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=551525;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{42})} to
#                              media\Tex\febe5d537d3360b8.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  44%|####4     | 267/600 [03:00<04:50,  1.15it/s]
# [12/28/23 15:57:25] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{43})} = E      ]8;id=994363;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=248861;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{43})} to
#                              media\Tex\71fe4c39ec936c6a.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  45%|####5     | 270/600 [03:03<04:49,  1.14it/s]
# [12/28/23 15:57:28] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{44})} = E      ]8;id=265009;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=527398;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{44})} to
#                              media\Tex\bc2cde066534d93a.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  46%|####5     | 273/600 [03:06<04:30,  1.21it/s]
# [12/28/23 15:57:31] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{45})} = E      ]8;id=281323;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=38335;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{45})} to
#                              media\Tex\c4aa6ae4c3fef7f9.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  46%|####5     | 275/600 [03:08<04:56,  1.10it/s]
# [12/28/23 15:57:33] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{46})} = E      ]8;id=600193;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=838407;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{46})} to
#                              media\Tex\a549849549f4d4ef.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  46%|####6     | 278/600 [03:11<04:27,  1.20it/s]
# [12/28/23 15:57:36] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{47})} = E      ]8;id=134239;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=986887;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{47})} to
#                              media\Tex\33a50fc61c6fcd2c.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  47%|####6     | 281/600 [03:14<04:15,  1.25it/s]
# [12/28/23 15:57:39] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{48})} = E      ]8;id=213605;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=789379;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{48})} to
#                              media\Tex\f9cc16e69146cd95.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  47%|####7     | 283/600 [03:16<04:45,  1.11it/s]
# [12/28/23 15:57:41] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{49})} = E      ]8;id=817594;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=560712;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{49})} to
#                              media\Tex\9312332a02fb2378.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  48%|####7     | 286/600 [03:19<04:20,  1.20it/s]
# [12/28/23 15:57:44] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{50})} = E      ]8;id=635305;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=430732;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{50})} to
#                              media\Tex\9a33ba9d3bcc342e.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  48%|####8     | 289/600 [03:21<04:03,  1.28it/s]
# [12/28/23 15:57:46] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{51})} = E      ]8;id=548895;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=216665;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{51})} to
#                              media\Tex\570b35ea9c8afa0c.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  48%|####8     | 291/600 [03:23<04:29,  1.15it/s]
# [12/28/23 15:57:48] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{52})} = E      ]8;id=825583;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=634318;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{52})} to
#                              media\Tex\49a4cbe749cdabbb.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  49%|####9     | 294/600 [03:26<04:03,  1.25it/s]
# [12/28/23 15:57:51] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{53})} = E      ]8;id=178119;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=586560;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{53})} to
#                              media\Tex\dd8181d1eb1bc00c.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  50%|####9     | 297/600 [03:29<03:54,  1.29it/s]
# [12/28/23 15:57:54] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{54})} = E      ]8;id=685459;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=674463;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{54})} to
#                              media\Tex\ce17fc7758da1bc7.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  50%|####9     | 299/600 [03:31<04:24,  1.14it/s]
# [12/28/23 15:57:56] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{55})} = E      ]8;id=358403;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=897361;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{55})} to
#                              media\Tex\7da44685e2e67664.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  50%|#####     | 302/600 [03:33<04:00,  1.24it/s]
# [12/28/23 15:57:58] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{56})} = E      ]8;id=67377;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=721270;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{56})} to
#                              media\Tex\f07740aea12360f7.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  51%|#####     | 304/600 [03:36<04:24,  1.12it/s]
# [12/28/23 15:58:01] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{57})} = E      ]8;id=459584;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=810432;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{57})} to
#                              media\Tex\76b6af189b2c7745.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  51%|#####1    | 307/600 [03:38<03:54,  1.25it/s]
# [12/28/23 15:58:03] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{58})} = E      ]8;id=377190;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=256682;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{58})} to
#                              media\Tex\0a93c0878d4c679a.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  52%|#####1    | 310/600 [03:41<03:44,  1.29it/s]
# [12/28/23 15:58:06] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{59})} = E      ]8;id=32675;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=838362;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{59})} to
#                              media\Tex\63aff82fffbb6380.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  52%|#####2    | 312/600 [03:43<04:14,  1.13it/s]
# [12/28/23 15:58:08] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{60})} = E      ]8;id=317042;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=181743;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{60})} to
#                              media\Tex\990753a0fcb32e9a.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  52%|#####2    | 315/600 [03:46<03:53,  1.22it/s]
# [12/28/23 15:58:11] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{61})} = E      ]8;id=363432;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=63616;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{61})} to
#                              media\Tex\f84d9cfb08b2f66d.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  53%|#####3    | 318/600 [03:48<03:44,  1.26it/s]
# [12/28/23 15:58:13] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{62})} = E      ]8;id=748652;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=381096;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{62})} to
#                              media\Tex\3f18dc5b3d3c5cfb.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  53%|#####3    | 320/600 [03:51<04:11,  1.11it/s]
# [12/28/23 15:58:16] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{63})} = E      ]8;id=542616;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=559356;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{63})} to
#                              media\Tex\dfe167adaf95bfc0.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  54%|#####3    | 323/600 [03:53<03:44,  1.23it/s]
# [12/28/23 15:58:18] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{64})} = E      ]8;id=337547;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=547749;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{64})} to
#                              media\Tex\0f8edafe25f3b2ad.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  54%|#####4    | 326/600 [03:56<03:36,  1.26it/s]
# [12/28/23 15:58:21] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{65})} = E      ]8;id=667935;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=605524;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{65})} to
#                              media\Tex\96b82e5a3020a8c0.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  55%|#####4    | 328/600 [03:58<04:02,  1.12it/s]
# [12/28/23 15:58:23] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{66})} = E      ]8;id=397073;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=593158;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{66})} to
#                              media\Tex\394dda1c411ade05.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  55%|#####5    | 331/600 [04:01<03:41,  1.21it/s]
# [12/28/23 15:58:26] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{67})} = E      ]8;id=798290;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=735542;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{67})} to
#                              media\Tex\30872f2da5107b13.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  56%|#####5    | 334/600 [04:04<03:43,  1.19it/s]
# [12/28/23 15:58:29] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{68})} = E      ]8;id=426075;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=909423;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{68})} to
#                              media\Tex\5bc4fad1937573b1.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  56%|#####6    | 337/600 [04:07<03:57,  1.11it/s]
# [12/28/23 15:58:32] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{69})} = E      ]8;id=268462;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=260042;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{69})} to
#                              media\Tex\9cd9e3f8242b9351.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  57%|#####6    | 340/600 [04:10<03:45,  1.15it/s]
# [12/28/23 15:58:35] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{70})} = E      ]8;id=442787;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=980958;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{70})} to
#                              media\Tex\935fd7c68fee36a7.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  57%|#####6    | 342/600 [04:12<04:04,  1.06it/s]
# [12/28/23 15:58:37] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{71})} = E      ]8;id=244514;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=327333;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{71})} to
#                              media\Tex\c4a99b6eca59f558.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  57%|#####7    | 345/600 [04:15<03:42,  1.15it/s]
# [12/28/23 15:58:40] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{72})} = E      ]8;id=996931;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=57422;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{72})} to
#                              media\Tex\64a7b4e55f0a859d.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  58%|#####8    | 348/600 [04:18<03:19,  1.27it/s]
# [12/28/23 15:58:43] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{73})} = E      ]8;id=760438;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=927014;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{73})} to
#                              media\Tex\bbe5d49759f6d6f5.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  59%|#####8    | 352/600 [04:21<03:02,  1.36it/s]
# [12/28/23 15:58:46] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{74})} = E      ]8;id=656326;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=219399;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{74})} to
#                              media\Tex\517bdb6cae5aa4e3.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  59%|#####9    | 355/600 [04:24<03:20,  1.22it/s]
# [12/28/23 15:58:49] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{75})} = E      ]8;id=259314;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=385906;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{75})} to
#                              media\Tex\8c8a85dab419bafd.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  60%|#####9    | 358/600 [04:27<03:17,  1.22it/s]
# [12/28/23 15:58:52] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{76})} = E      ]8;id=143660;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=598468;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{76})} to
#                              media\Tex\f412ab9b6e880c3d.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  60%|######    | 361/600 [04:30<03:05,  1.29it/s]
# [12/28/23 15:58:55] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{77})} = E      ]8;id=869839;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=730367;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{77})} to
#                              media\Tex\a7a56a3af3498e67.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  61%|######    | 364/600 [04:32<02:56,  1.34it/s]
# [12/28/23 15:58:57] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{78})} = E      ]8;id=211745;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=806916;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{78})} to
#                              media\Tex\8e1a5c512943791d.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  61%|######1   | 368/600 [04:35<02:37,  1.47it/s]
# [12/28/23 15:59:00] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{79})} = E      ]8;id=181978;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=910144;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{79})} to
#                              media\Tex\4cfd52c24da6aea4.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  62%|######2   | 372/600 [04:38<02:33,  1.48it/s]
# [12/28/23 15:59:03] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{80})} = E      ]8;id=867792;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=345836;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{80})} to
#                              media\Tex\9f561826ca1bb337.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  62%|######2   | 375/600 [04:41<02:43,  1.37it/s]
# [12/28/23 15:59:06] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{81})} = E      ]8;id=588612;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=708269;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{81})} to
#                              media\Tex\d057d6114927fdac.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  63%|######3   | 379/600 [04:44<02:36,  1.41it/s]
# ...
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{89})} to
#                              media\Tex\37085c22c94a4c52.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  70%|######9   | 417/600 [05:14<01:50,  1.66it/s]
# [12/28/23 15:59:39] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{90})} = E      ]8;id=238497;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=642793;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{90})} to
#                              media\Tex\c1dffea5f78088ce.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  70%|#######   | 423/600 [05:18<01:45,  1.68it/s]
# [12/28/23 15:59:43] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{91})} = E      ]8;id=625691;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=73060;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{91})} to
#                              media\Tex\b585dab78a16f25e.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  72%|#######1  | 430/600 [05:23<01:36,  1.76it/s]
# [12/28/23 15:59:48] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{92})} = E      ]8;id=20681;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=279127;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{92})} to
#                              media\Tex\35d4deddd3251c6a.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  73%|#######2  | 437/600 [05:28<01:32,  1.77it/s]
# [12/28/23 15:59:53] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{93})} = E      ]8;id=10373;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=182680;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{93})} to
#                              media\Tex\8f03da2d1177ca59.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  74%|#######4  | 445/600 [05:33<01:25,  1.82it/s]
# [12/28/23 15:59:58] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{94})} = E      ]8;id=597307;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=708664;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{94})} to
#                              media\Tex\b5145c04d6afab68.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  76%|#######5  | 454/600 [05:39<01:20,  1.81it/s]
# [12/28/23 16:00:04] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{95})} = E      ]8;id=12136;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=696734;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{95})} to
#                              media\Tex\39a1dc0b99d6c697.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  78%|#######7  | 465/600 [05:46<01:12,  1.87it/s]
# [12/28/23 16:00:11] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{96})} = E      ]8;id=573538;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=936232;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{96})} to
#                              media\Tex\a4fcbd5d2af32f61.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  80%|#######9  | 477/600 [05:53<01:05,  1.87it/s]
# [12/28/23 16:00:18] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{97})} = E      ]8;id=316634;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=414266;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{97})} to
#                              media\Tex\ed85599f9447c5b8.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  82%|########2 | 492/600 [06:02<00:57,  1.87it/s]
# [12/28/23 16:00:27] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{98})} = E      ]8;id=833059;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=208446;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{98})} to
#                              media\Tex\007ac0e4eac1d0a2.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  86%|########5 | 513/600 [06:15<00:46,  1.87it/s]
# [12/28/23 16:00:40] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{99})} = E      ]8;id=375129;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=11099;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{99})} to
#                              media\Tex\7915c4cf55e5f305.tex
# Animation 6: Transform(VGroup of 350 submobjects), etc.:  90%|######### | 542/600 [06:32<00:32,  1.78it/s]
# [12/28/23 16:00:57] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{100})} = E     ]8;id=217412;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=79559;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{100})} to
#                              media\Tex\34ea1510d3a03fcc.tex
# [12/28/23 16:01:40] INFO     Writing \hat{H} \ket{\psi(r_1, r_2, r_3, ..., r_{101})} = E     ]8;id=13517;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=815039;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\tex_file_writing.py#89\89]8;;\
#                              \ket{\psi(r_1, r_2, r_3, ..., r_{101})} to
#                              media\Tex\128d90c98bc41978.tex
# [12/28/23 16:01:41] INFO     Animation 6 : Partial movie file written in                   ]8;id=317205;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=827471;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\partial_movie_files\IntroScene\4245490092_1609682902_
#                              3201014746.mp4'
# [12/28/23 16:04:05] INFO     Animation 7 : Partial movie file written in                   ]8;id=637597;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=745550;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\partial_movie_files\IntroScene\4245490092_3135357775_
#                              2269223676.mp4'
# [12/28/23 16:04:06] INFO     Animation 8 : Partial movie file written in                   ]8;id=498375;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=388729;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\partial_movie_files\IntroScene\4245490092_1740919036_
#                              73661187.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=670617;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=865029;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#607\607]8;;\
# [12/28/23 16:04:07] INFO                                                                   ]8;id=629052;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=457987;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\IntroScene.mp4'
#                     INFO     Rendered IntroScene                                                       ]8;id=400149;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=676144;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 9 animations
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-b3b8dd0900b8> in <module>
# ----> 1 get_ipython().run_cell_magic('manim', '-qh -r 1080,1920 IntroScene', '\nclass IntroScene(Scene):\n    def construct(self):\n        # PARTICLES IN A BOX\n        size = 6.5\n        box = Rectangle(width=size, height=size)\n\n        def particle_updater(obj):\n            x_coord = obj.get_x()\n            y_coord = obj.get_y()\n\n            d1 = np.random.uniform(low=-0.04, high=0.04)\n            d2 = np.random.uniform(low=-0.03, high=0.03)\n\n            # new coords\n            x_new = x_coord+d1\n            y_new = y_coord+d2\n            if x_coord+d1 > 6:\n                x_new = x_coord-d1\n            elif x_coord+d1 < -6:\n                x_new = x_coord-d1\n            \n            if y_coord+d2 > 6:\n                y_new = y_coord-d2\n            elif y_coord+d2 < -6:\n                y_new = y_coord-d2\n\n            #x_new = x_coord+d1 if (x_coord+d1 < 6) else x_coord-d1\n            #y_new = y_coord+d2 if (y_coord+d2 < 6) else y_coord-d2\n            obj.move_to([x_new, y_new, 0])\n\n        def generate_particles(N, update=True, pos=[-2.4, 2.4]):\n            particles = VGroup()\n            for i in range(N):\n                # generate dot with random color\n                rand = lambda: np.random.uniform(low=0.0, high=1.0)\n                color = rgb_to_color([rand(), rand(), rand()])\n\n                dot = Dot(color=color).scale(.5)\n\n                # random position to dot\n                loc = np.array(\n                    [\n                        np.random.uniform(low=pos[0], high=pos[1]),\n                        np.random.uniform(low=pos[0], high=pos[1]),\n                        0\n                    ]\n                )\n\n                dot.move_to(loc)\n                \n                if update:\n                    dot.add_updater(particle_updater)\n                particles += dot\n\n            return particles\n\n        p1 = generate_particles(1, pos=[-.02, .02])\n        p2 = generate_particles(2, pos=[-.04, .04])\n        p3 = generate_particles(3, pos=[-.2, .2])\n        p4 = generate_particles(10, pos=[-.2, .2])\n        p5 = generate_particles(350)\n\n        # LATEX EOM\n        # tex package\n        myTemplate = TexTemplate()\n        myTemplate.add_to_preamble(r"\\usepackage{braket}")\n\n        # wavefunction strings\n        index = ValueTracker(10)\n        f1 = r"\\hat{H} \\ket{\\psi(r_1)} = E \\ket{\\psi(r_1)}"\n        f2 = r"\\hat{H} \\ket{\\psi(r_1, r_2)} = E \\ket{\\psi(r_1, r_2)}"\n        f3 = r"\\hat{H} \\ket{\\psi(r_1, r_2, r_3)} = E \\ket{\\psi(r_1, r_2, r_3)}"\n        f4 = r"\\hat{H} \\ket{\\psi(r_1, r_2, r_3, ..., r_{10})} = E \\ket{\\psi(r_1, r_2, r_3, ..., r_{10})}"\n\n        wf1 = MathTex(\n            f1,\n            tex_template=myTemplate\n        ).next_to(box, UP)\n        wf2 = MathTex(\n            f2,\n            tex_template=myTemplate\n        ).next_to(box, UP)\n        wf3 = MathTex(\n            f3,\n            tex_template=myTemplate\n        ).next_to(box, UP)\n        wf4 = MathTex(\n            f4,\n            tex_template=myTemplate\n        ).next_to(box, UP)\n        wfn = always_redraw(lambda: MathTex(\n            r"\\hat{{H}} \\ket{{\\psi(r_1, r_2, r_3, ..., r_{{{arg}}})}} = E \\ket{{\\psi(r_1, r_2, r_3, ..., r_{{{arg}}})}}".format(arg=int(index.get_value())),\n            tex_template=myTemplate\n        ).next_to(box, UP))\n\n        # SCENE\n        animations = [\n            (Transform(p4, p5, run_time=12)),\n            index.animate.set_value(101)\n        ]\n\n        self.play(FadeIn(box), run_time=0.5)\n        self.play(  \n            Create(p1),\n            run_time=3\n        )\n        self.play(Write(wf1))\n        self.play(\n            Transform(p1, p2),\n            TransformMatchingShapes(wf1, wf2),\n            run_time=2\n            )\n        self.play(\n            Transform(p2, p3),\n            TransformMatchingShapes(wf2, wf3),\n            run_time=2\n        )\n        self.pla ...
#
# c:\Users\Zach\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2360             with self.builtin_trap:
#    2361                 args = (magic_arg_s, cell)
# -> 2362                 result = fn(*args, **kwargs)
#    2363             return result
#    2364
#
# c:\Users\Zach\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# c:\Users\Zach\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\ipython_magic.py in manim(self, line, cell, local_ns)
#     189                         tmpfile,
#     190                         html_attributes=f'controls autoplay loop style="max-width: {config["media_width"]};"',
# --> 191                         embed=embed,
#     192                     )
#     193
#
# TypeError: __init__() got an unexpected keyword argument 'html_attributes'

# %%
# %%manim -qh -r 1080,1920 SpinScene
#
# class SpinScene(Scene):
#     def construct(self):
#         myTemplate = TexTemplate()
#         myTemplate.add_to_preamble(r"\usepackage{amsmath}")
#         def create_arrows(arrows=[], n=11, labels=True):
#             '''
#             params:
#             - arrows: "u" - up, "d" - down
#             - n: number of arrows
#             '''
#             group = VGroup()
#
#             # generate n arrows randomly
#             if not arrows:
#                 for i in np.arange(1, n, 1):
#                     rand = np.random.randint(10)
#
#                     label = Text(f'{i + 1}').scale(.8)
#                     if rand > 5:
#                         a = Arrow(start=ORIGIN, end=config.top).shift(RIGHT*i)
#                         group += a
#                         if labels:
#                             label.next_to(a, DOWN)
#                             group += label
#
#                     else:
#                         a = Arrow(start=config.top, end=ORIGIN).shift(RIGHT*i)
#                         group += a
#                         if labels:
#                             label.next_to(a, DOWN)
#                             group += label
#
#
#             # generate n arrows by evaluating the arrows array parameter
#             else:
#                 for i, arr in enumerate(arrows):
#                     label = Text(f'{i + 1}').scale(.8)
#                     if arr == "u":
#                         a = Arrow(start=ORIGIN, end=config.top).shift(RIGHT*i)
#                         group += a
#                         if labels:
#                             label.next_to(a, DOWN)
#                             group += label
#                     else:
#                         a = Arrow(start=config.top, end=ORIGIN).shift(RIGHT*i)
#                         group += a
#                         if labels:
#                             label.next_to(a, DOWN)
#                             group += label
#
#             return group
#
#         arrows = create_arrows(
#             ["u", "d", "u", "d", "d", "u", "d", "u", "u", "u"]
#         )
#
#         # generate legend
#         legend_title = Text("Magnetic Moment", color=BLUE).scale(.9).shift([0, 4, 0])
#         a_u = create_arrows(["u"], labels=False).scale(.5).shift([-3, 0, 0])
#         l_u = Text(" = +m").next_to(a_u, RIGHT)
#         a_d = create_arrows(["d"], labels=False).scale(.5).shift([1, 0, 0])
#         l_d = Text(" = -m").next_to(a_d, RIGHT)
#         legend = VGroup(legend_title, a_u, l_u, a_d, l_d)
#
#         arrows.center()
#         legend.center()
#
#         # 2 moment example
#         state_num = MathTex(
#             r"2^N",
#             color=BLUE
#         )
#         state_descrip = Text("For N spins", color=BLUE).next_to(state_num, UP).scale(.9).shift([1.2,0,0])
#         state_descrip1 = Text("possible states", color=BLUE).next_to(state_num, RIGHT).scale(.9)
#         title_group = VGroup(state_descrip, state_num, state_descrip1).center().shift([0, 8, 0])
#         ex_title = Text("Example: N = 2").scale(.8).shift([0, 6, 0])
#
#         s1 = create_arrows(
#             ["u", "u"]
#         ).shift([-4, 1, 0]).scale(.8)
#
#         s2 = create_arrows(
#             ["u", "d"]
#         ).shift([-4, -4, 0]).scale(.8)
#
#         s3 = create_arrows(
#             ["d", "u"]
#         ).shift([4, 1, 0]).scale(.8)
#
#         s4 = create_arrows(
#             ["d", "d"]
#         ).shift([4, -4, 0]).scale(.8)
#
#         ex_group = VGroup(
#             title_group,
#             ex_title,
#             s1,
#             s2,
#             s3,
#             s4
#         )
#
#         # generating function / multiplication rule
#         prod_descrip = Text("All Possible States: ", color=BLUE).scale(.9).shift([0, 2, 0])
#         n_prod = MathTex(
#             r"(\uparrow_1 + \downarrow_1)(\uparrow_2 + \downarrow_2)(\uparrow_3 + \downarrow_3)...(\uparrow_N + \downarrow_N)"
#         ).next_to(prod_descrip, DOWN)
#
#         two_prod_descrip = Text("For N = 2 ", color=BLUE).scale(.9).shift([0, -2, 0])
#         two_prod = MathTex(
#             r"(\uparrow_1 + \downarrow_1)(\uparrow_2 + \downarrow_2) =\ \uparrow_1 \uparrow_2 + \uparrow_1 \downarrow_2 + \downarrow_1 \uparrow_2 + \downarrow_1 \downarrow_2 "
#         ).next_to(two_prod_descrip, DOWN)
#
#         frame = SurroundingRectangle(two_prod[0][0:14], buff=.1, color=BLUE).shift([0, 2.7, 0])
#         frame_descrip = Text("Generating Function", color=BLUE).scale(.9).next_to(frame, UP)
#
#         # N = 3 and macrostates
#         three_prod = MathTex(
#             r"(\uparrow_1 + \downarrow_1)(\uparrow_2 + \downarrow_2)(\uparrow_3 + \downarrow_3)"
#         ).shift([0, 1, 0])
#
#         total_M = Text("Magnetization (Total Magnetic Moment) M: ", color=BLUE).scale(0.9).shift([0, 4, 0])
#         M_calc = MathTex(
#             r"M = m(N_{\uparrow} - N_{\downarrow})"
#         ).next_to(total_M, DOWN)
#
#         M_group = VGroup(total_M, M_calc)
#
#         frame_mag = SurroundingRectangle(M_calc[0][4:9], buff=.1, color=BLUE)
#         frame_mag_descrip = Text("Spin Excess", color=BLUE).scale(.8).next_to(frame_mag, DOWN)
#
#         m1 = MathTex(
#             r"&M = 3m",
#             r"&\uparrow_1 \uparrow_2 \uparrow_3 \\",
#             r"&M = m",
#             r"&\uparrow_1 \uparrow_2 \downarrow_3 \ \ \uparrow_1 \downarrow_2 \uparrow_3 \ \ \downarrow_1 \uparrow_2 \uparrow_3 \\",
#             r"&M = -m",
#             r"&\uparrow_1 \downarrow_2 \downarrow_3 \ \ \downarrow_1 \uparrow_2 \downarrow_3 \ \ \downarrow_1 \downarrow_2 \uparrow_3 \\",
#             r"&M = -3m",
#             r"&\downarrow_1 \downarrow_2 \downarrow_3 \\",
#             tex_template=myTemplate
#         ).shift([0, -2, 0])
#
#         # multiplicity and state enumeration
#
#         # SCENE
#         self.play(Write(arrows))
#         self.wait(1)
#         self.play(arrows.animate.move_to([0, 8.5, 0]))
#
#         self.play(Write(legend))
#         self.wait(2)
#
#         self.play(Unwrite(arrows), Unwrite(legend))
#         self.play(Write(ex_group))
#         self.wait(2)
#
#         self.play(Unwrite(ex_group))
#
#         self.play(Write(prod_descrip), Write(n_prod))
#         self.play(Write(two_prod_descrip), Write(two_prod))
#         self.wait(4)
#
#         self.play(Unwrite(prod_descrip), Unwrite(n_prod), Unwrite(two_prod_descrip))
#         self.play(two_prod.animate.center())
#         self.play(Write(frame), Write(frame_descrip))
#         self.wait(3)
#
#         self.play(Unwrite(frame), Unwrite(frame_descrip), Unwrite(two_prod))
#         self.play(Write(M_group))
#         #self.play(Write(frame_mag), Write(frame_mag_descrip))
#         self.wait(2)
#         #self.play(Unwrite(frame_mag), Unwrite(frame_mag_descrip))
#
#
#         self.play(Write(three_prod))
#         self.play(Write(m1))
#         self.wait(6)
#         self.play(Unwrite(M_group), Unwrite(m1), Unwrite(three_prod))
#         self.wait(2)
# Out:
# [12/28/23 17:50:46] INFO     Animation 0 : Using cached data (hash :                           ]8;id=994299;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=494027;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4222611999_3628229190_223132457)
# [12/28/23 17:50:47] INFO     Animation 1 : Using cached data (hash :                           ]8;id=369296;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=368469;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_1329314881_2357128908)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=336530;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=494733;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_1143537775_793993427)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=675692;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=703095;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_864487482_3241380899)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=792453;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=687549;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_1740919036_2785917060)
# [12/28/23 17:50:48] INFO     Animation 5 : Using cached data (hash :                           ]8;id=768331;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=430900;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_2230323021_3598655)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=877561;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=318092;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_1443011154_3828168139)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=907689;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=34458;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_1740919036_1686754259)
# [12/28/23 17:50:49] INFO     Animation 8 : Using cached data (hash :                           ]8;id=116975;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=774566;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_1727856989_1417369488)
#                     INFO     Animation 9 : Using cached data (hash :                           ]8;id=277229;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=288798;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_4112180493_2518773252)
# [12/28/23 17:50:50] INFO     Animation 10 : Using cached data (hash :                          ]8;id=624214;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=477805;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_3448510465_4200056771)
#                     INFO     Animation 11 : Using cached data (hash :                          ]8;id=647839;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=331976;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_4016927065_3056434010)
#                     INFO     Animation 12 : Using cached data (hash :                          ]8;id=697179;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=488169;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_2166331926_2841253291)
#                     INFO     Animation 13 : Using cached data (hash :                          ]8;id=481422;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=471239;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_687853408_3066428464)
# [12/28/23 17:50:51] INFO     Animation 14 : Using cached data (hash :                          ]8;id=246628;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=137455;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_375209643_929824273)
#                     INFO     Animation 15 : Using cached data (hash :                          ]8;id=674093;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=819653;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_1149804837_1573769932)
#                     INFO     Animation 16 : Using cached data (hash :                          ]8;id=529546;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=946390;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_2145115100_721457773)
# [12/28/23 17:50:52] INFO     Animation 17 : Using cached data (hash :                          ]8;id=229505;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=384824;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_1533507159_897544487)
#                     INFO     Animation 18 : Using cached data (hash :                          ]8;id=163528;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=573087;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_957343386_1446337947)
#                     INFO     Animation 19 : Using cached data (hash :                          ]8;id=577533;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=889369;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_1070397070_567615056)
# [12/28/23 17:50:53] INFO     Animation 20 : Using cached data (hash :                          ]8;id=935363;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=299077;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_3042001944_437117094)
# [12/28/23 17:50:57] INFO     Animation 21 : Partial movie file written in                  ]8;id=713605;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=442909;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\partial_movie_files\SpinScene\4245490092_342097447_27
#                              26087817.mp4'
# [12/28/23 17:51:04] INFO     Animation 22 : Partial movie file written in                  ]8;id=761239;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=528059;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\partial_movie_files\SpinScene\4245490092_2019257805_1
#                              0987111.mp4'
# [12/28/23 17:51:05] INFO     Animation 23 : Partial movie file written in                  ]8;id=240330;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=863859;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\partial_movie_files\SpinScene\4245490092_1740919036_2
#                              239806390.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=913954;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=103152;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#607\607]8;;\
#                     INFO                                                                   ]8;id=742084;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=768106;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\SpinScene.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=176633;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=533822;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#700\700]8;;\
#                              manim has removed the 3 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered SpinScene                                                        ]8;id=877523;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=796481;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 24 animations
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-a1bcc9c64152> in <module>
# ----> 1 get_ipython().run_cell_magic('manim', '-qh -r 1080,1920 SpinScene', '\nclass SpinScene(Scene):\n    def construct(self):\n        myTemplate = TexTemplate()\n        myTemplate.add_to_preamble(r"\\usepackage{amsmath}")\n        def create_arrows(arrows=[], n=11, labels=True):\n            \'\'\'\n            params:\n            - arrows: "u" - up, "d" - down\n            - n: number of arrows\n            \'\'\'\n            group = VGroup()\n            \n            # generate n arrows randomly\n            if not arrows:\n                for i in np.arange(1, n, 1):\n                    rand = np.random.randint(10)\n\n                    label = Text(f\'{i + 1}\').scale(.8)\n                    if rand > 5:\n                        a = Arrow(start=ORIGIN, end=config.top).shift(RIGHT*i)\n                        group += a\n                        if labels:\n                            label.next_to(a, DOWN)\n                            group += label\n\n                    else:\n                        a = Arrow(start=config.top, end=ORIGIN).shift(RIGHT*i)\n                        group += a\n                        if labels:\n                            label.next_to(a, DOWN)\n                            group += label\n\n\n            # generate n arrows by evaluating the arrows array parameter\n            else:\n                for i, arr in enumerate(arrows):\n                    label = Text(f\'{i + 1}\').scale(.8)\n                    if arr == "u":\n                        a = Arrow(start=ORIGIN, end=config.top).shift(RIGHT*i)\n                        group += a\n                        if labels:\n                            label.next_to(a, DOWN)\n                            group += label\n                    else: \n                        a = Arrow(start=config.top, end=ORIGIN).shift(RIGHT*i) \n                        group += a\n                        if labels:\n                            label.next_to(a, DOWN)\n                            group += label\n\n            return group\n\n        arrows = create_arrows(\n            ["u", "d", "u", "d", "d", "u", "d", "u", "u", "u"]\n        )\n\n        # generate legend\n        legend_title = Text("Magnetic Moment", color=BLUE).scale(.9).shift([0, 4, 0])\n        a_u = create_arrows(["u"], labels=False).scale(.5).shift([-3, 0, 0])\n        l_u = Text(" = +m").next_to(a_u, RIGHT)\n        a_d = create_arrows(["d"], labels=False).scale(.5).shift([1, 0, 0])\n        l_d = Text(" = -m").next_to(a_d, RIGHT)\n        legend = VGroup(legend_title, a_u, l_u, a_d, l_d)\n\n        arrows.center()\n        legend.center()\n\n        # 2 moment example\n        state_num = MathTex(\n            r"2^N",\n            color=BLUE\n        )\n        state_descrip = Text("For N spins", color=BLUE).next_to(state_num, UP).scale(.9).shift([1.2,0,0])\n        state_descrip1 = Text("possible states", color=BLUE).next_to(state_num, RIGHT).scale(.9)\n        title_group = VGroup(state_descrip, state_num, state_descrip1).center().shift([0, 8, 0])\n        ex_title = Text("Example: N = 2").scale(.8).shift([0, 6, 0])\n\n        s1 = create_arrows(\n            ["u", "u"]\n        ).shift([-4, 1, 0]).scale(.8)\n\n        s2 = create_arrows(\n            ["u", "d"]\n        ).shift([-4, -4, 0]).scale(.8)\n\n        s3 = create_arrows(\n            ["d", "u"]\n        ).shift([4, 1, 0]).scale(.8)\n\n        s4 = create_arrows(\n            ["d", "d"]\n        ).shift([4, -4, 0]).scale(.8)\n\n        ex_group = VGroup(\n            title_group,\n            ex_title,\n            s1,\n            s2,\n            s3,\n            s4\n        )\n\n        # generating function / multiplication rule\n        prod_descrip = Text("All Possible States: ", color=BLUE).scale(.9).shift([0, 2, 0])\n        n_prod = MathTex(\n            r"(\\uparrow_1 + \\downarrow_1)(\\uparrow_2 + \\downarrow_2)(\\uparrow_3 + \\downarrow_3)...(\\uparrow_N + \\downarrow_N)"\n        ).next_to(prod_descr ...
#
# c:\Users\Zach\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2360             with self.builtin_trap:
#    2361                 args = (magic_arg_s, cell)
# -> 2362                 result = fn(*args, **kwargs)
#    2363             return result
#    2364
#
# c:\Users\Zach\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# c:\Users\Zach\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\ipython_magic.py in manim(self, line, cell, local_ns)
#     189                         tmpfile,
#     190                         html_attributes=f'controls autoplay loop style="max-width: {config["media_width"]};"',
# --> 191                         embed=embed,
#     192                     )
#     193
#
# TypeError: __init__() got an unexpected keyword argument 'html_attributes'

# %%
# %%manim -qh -r 1080,1920 Quote
#
# class Quote(Scene):
#     def construct(self):
#         lines = [
#             "\"The laws of thermodynamics may easily be",
#             "obtained from the principles of",
#             "statistical mechanics, of which they",
#             "are the incomplete expression.\""
#         ]
#         # quote = Text(
#         #     "\"The laws of thermodynamics may easily be \n obtained from the principles of \n statistical mechanics, of which they are \n the incomplete expression.\"",
#         #     t2c={'thermodynamics':RED, 'statistical mechanics':RED},
#
#         quote = VGroup()
#         for i, val in enumerate(lines):
#             q = Text(
#                 f'{val}',
#                 t2c={'thermodynamics':RED, 'statistical mechanics':RED},
#             )
#             if i > 0:
#                 q.align_to(quote[i-1], LEFT)
#                 q.shift([0, -i*1.03, 0])
#             quote += q
#
#         author = Text("Gibbs", weight="BOLD").next_to(quote, DOWN).shift([2,0,0])
#         total = VGroup(quote, author).shift([0, 2, 0])
#
#         self.play(Write(total))
# Out:
# [12/20/23 01:29:34] INFO     Animation 0 : Partial movie file written in                   ]8;id=910573;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=78039;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\partial_movie_files\Quote\4222611999_1269349307_22313
#                              2457.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=208044;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=773378;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#607\607]8;;\
#                     INFO                                                                   ]8;id=84776;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=258675;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\Quote.mp4'
#                     INFO     Rendered Quote                                                            ]8;id=642507;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=934404;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 1 animations
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-1ad4087afbb2> in <module>
# ----> 1 get_ipython().run_cell_magic('manim', '-qh -r 1080,1920 Quote', '\nclass Quote(Scene):\n    def construct(self):\n        lines = [\n            "\\"The laws of thermodynamics may easily be",\n            "obtained from the principles of",\n            "statistical mechanics, of which they",\n            "are the incomplete expression.\\""\n        ]\n        # quote = Text(\n        #     "\\"The laws of thermodynamics may easily be \\n obtained from the principles of \\n statistical mechanics, of which they are \\n the incomplete expression.\\"",\n        #     t2c={\'thermodynamics\':RED, \'statistical mechanics\':RED},\n        \n        quote = VGroup()\n        for i, val in enumerate(lines):\n            q = Text(\n                f\'{val}\',\n                t2c={\'thermodynamics\':RED, \'statistical mechanics\':RED},\n            )\n            if i > 0:\n                q.align_to(quote[i-1], LEFT)\n                q.shift([0, -i*1.03, 0])\n            quote += q\n\n        author = Text("Gibbs", weight="BOLD").next_to(quote, DOWN).shift([2,0,0])\n        total = VGroup(quote, author).shift([0, 2, 0])\n\n        self.play(Write(total))\n')
#
# c:\Users\Zach\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2360             with self.builtin_trap:
#    2361                 args = (magic_arg_s, cell)
# -> 2362                 result = fn(*args, **kwargs)
#    2363             return result
#    2364
#
# c:\Users\Zach\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# c:\Users\Zach\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\ipython_magic.py in manim(self, line, cell, local_ns)
#     189                         tmpfile,
#     190                         html_attributes=f'controls autoplay loop style="max-width: {config["media_width"]};"',
# --> 191                         embed=embed,
#     192                     )
#     193
#
# TypeError: __init__() got an unexpected keyword argument 'html_attributes'

# %%
# %%manim -qh -r 1080,1920 StateCounting
#
# class StateCounting(Scene):
#     def construct(self):
#         myTemplate = TexTemplate()
#         myTemplate.add_to_preamble(r"\usepackage{amsmath}")
#
#         title = Text("Counting States", color=BLUE).shift([0,8,0])
#
#         up_d = Text("# of states with +m").scale(.7).shift([-3, 6, 0])
#         up_t = MathTex(
#             r"N_{\uparrow} = \frac{1}{2}N + s"
#         ).next_to(up_d, DOWN)
#
#         down_d = Text("# of states with -m").scale(.7).shift([3, 6, 0])
#         down_t = MathTex(
#             r"N_{\downarrow} = \frac{1}{2}N - s"
#         ).next_to(down_d, DOWN)
#         num_group = VGroup(up_d, up_t, down_d, down_t)
#
#         se = MathTex(
#             r"N_{\uparrow} - N_{\downarrow} = 2s"
#         ).shift([0,3.5,0])
#         frame = SurroundingRectangle(se[0][6:8], buff=.1, color=BLUE)
#         se_d = Text("Spin Excess", color=BLUE).next_to(frame, DOWN).scale(.7)
#
#         m1 = MathTex(
#             r"&M = 3m",
#             r"&\uparrow_1 \uparrow_2 \uparrow_3 \\",
#             r"&M = m",
#             r"&\uparrow_1 \uparrow_2 \downarrow_3 \ \ \uparrow_1 \downarrow_2 \uparrow_3 \ \ \downarrow_1 \uparrow_2 \uparrow_3 \\",
#             r"&M = -m",
#             r"&\uparrow_1 \downarrow_2 \downarrow_3 \ \ \downarrow_1 \uparrow_2 \downarrow_3 \ \ \downarrow_1 \downarrow_2 \uparrow_3 \\",
#             r"&M = -3m",
#             r"&\downarrow_1 \downarrow_2 \downarrow_3 \\",
#         ).next_to(se_d, DOWN).shift([-1.5, -1, 0])
#
#
#         m2 = MathTex(
#             r"&2s = 3 \\",
#             r"&2s = 1 \\",
#             r"&2s = -1 \\",
#             r"&2s = -3 \\"
#         ).shift(m1.get_critical_point(UL)).shift([1, -1.215, 0])
#
#         gen = MathTex(
#             r"(\uparrow + \downarrow)^N"
#         ).shift([0,1,0])
#
#         gen1 = MathTex(
#             r"(\uparrow + \downarrow)^N = \ ?"
#         )
#
#         gen_two = MathTex(
#             r"(\uparrow + \downarrow)^2 = \uparrow \uparrow + 2\uparrow \downarrow + \downarrow \downarrow"
#         ).next_to(gen, DOWN)
#
#         # n choose N_up
#         n_up = MathTex(
#             r"{N \choose N_{\uparrow}}",
#             r"&= \frac{N!}{(N-N_\uparrow)! N_{\uparrow}!}"
#             r"= \frac{N!}{N_{\downarrow}! N_{\uparrow}!} \\ \\",
#             r"{N \choose s} &= \frac{N!}{(\frac{1}{2}N - s)!(\frac{1}{2}N + s)}",
#             r"= \frac{N!}{N_{\downarrow}! N_{\uparrow}!}"
#         ).next_to(gen1, DOWN).shift([0, -1, 0])
#
#         n_frame = Underline(n_up[1][4:9], color=BLUE)
#         frame_tex = MathTex(
#             r"N_{\downarrow}"
#         ).next_to(n_frame, DOWN)
#
#         # s_up = MathTex(
#         #     r"{N \choose s} = \frac{N!}{(\frac{1}{2}N - s)!(\frac{1}{2}N + s)}",
#         # ).next_to(n_up, DOWN)
#
#         binomial = MathTex(
#             r"(x + y)^N &= \sum^N_{t=0} {N \choose t} x^{N-t}y^t \\",
#             r"&= x^N + N x^{N-1} y + \frac{1}{2} N(N-1) x^{N-2} y^2 + ... + y^N \\",
#             r"&= \sum^N_{t=0} \frac{N!}{(N-t)!t!} x^{N-t} y^t \\"
#         ).next_to(gen, DOWN).shift([0,-1,0])
#
#         sub = MathTex(
#             r"t \rightarrow \frac{1}{2}N - s"
#         )
#
#         gen_binomial = MathTex(
#             r"(\uparrow + \downarrow)^N &= \sum^{\frac{1}{2}N}_{s=-\frac{1}{2}N} {N \choose s} \uparrow^{\frac{1}{2}N + s}\downarrow^{\frac{1}{2}N - s} \\",
#             r"&= \sum_s \frac{N!}{(\frac{1}{2}N + s)!(\frac{1}{2}N - s)!} \uparrow^{\frac{1}{2}N + s}\downarrow^{\frac{1}{2}N - s} \\"
#         ).center().shift([0, 2, 0])
#
#         sub = MathTex(
#             r"t \rightarrow \frac{1}{2}N - s"
#         ).next_to(binomial, DOWN)
#
#         gen_frame = SurroundingRectangle(gen_binomial[1][3:10], buff=.1, color=BLUE)
#
#         multip_text = Text("Multiplicity Function", color=BLUE).next_to(gen_binomial, DOWN).shift([0, -1, 0])
#
#         multip = MathTex(
#             r"g(N,s) = \frac{N!}{(\frac{1}{2}N + s)!(\frac{1}{2}N - s)!} = \frac{N!}{N_{\uparrow}! N_{\downarrow}!}"
#         ).next_to(multip_text, DOWN).shift([0, -.5, 0])
#
#         multip1 = MathTex(
#             r"g(N,s) = \frac{N!}{N_{\uparrow}! N_{\downarrow}!}"
#         ).shift([0, 5.5, 0])
#
#         num_states = MathTex(
#             r"(\uparrow + \downarrow)^N = \sum^{\frac{1}{2}N}_{s=-\frac{1}{2}N} g(N,s) \uparrow^{\frac{1}{2}N + s}\downarrow^{\frac{1}{2}N - s}  "
#         ).next_to(multip, DOWN).shift([0, -.5, 0])
#
#         four_example = Text("E.g., N = 4").scale(.8).shift([0, -.5, 0])
#
#         four_exp = MathTex(
#             r"(\uparrow + \downarrow)^4 &= \sum^{2}_{-2} g(4, s) \uparrow^{2+s} \downarrow^{2-s} \\",
#             r"&= g(4,-2) \uparrow^{0} \downarrow^{4} + g(4, -1) \uparrow^{1} \downarrow^{3} + g(4, 0) \uparrow^{2} \downarrow^{2} \\ &+ g(4, 1) \uparrow^{3} \downarrow^{1} + g(4, 2) \uparrow^{4} \downarrow^{0}"
#         ).next_to(four_example, DOWN).shift([-.2, -.8, 0])
#
#         #frame_one = SurroundingRectangle()
#
#         #frame_three = SurroundingRectangle()
#
#         one_und = Underline(four_exp[1][1:12], color=BLUE)
#         three_und = Underline(four_exp[1][25:35], color=BLUE)
#
#         term_one = MathTex(
#             r"g(4, -2) \uparrow^{0} \downarrow^{4}",
#             r"=\frac{4!}{0!4!} \uparrow^{0} \downarrow^{4} = 1 \uparrow^{0} \downarrow^{4}",
#             color=BLUE
#         ).next_to(four_exp, DOWN).shift([0, -.7, 0])
#
#         term_one_symbols = MathTex(
#             r"\downarrow \downarrow \downarrow \downarrow",
#             color=BLUE
#         ).next_to(term_one, DOWN).shift([0, -.5, 0])
#
#         term_three = MathTex(
#             r"g(4, 0) \uparrow^{2} \downarrow^{2}",
#             r"&= \frac{4!}{2!2!} \uparrow^{2} \downarrow^{2} \\",
#             r"&= \frac{4*3*2*1}{(2*1)(2*1)} \uparrow^{2} \downarrow^{2} = 6 \uparrow^{2} \downarrow^{2}",
#             color=BLUE
#         ).next_to(four_exp, DOWN).shift([0, -.7, 0])
#
#         term_three_symbols = MathTex(
#             r"\uparrow \uparrow \downarrow \downarrow \ \downarrow \downarrow \uparrow \uparrow \ \uparrow \downarrow \downarrow \uparrow \ \downarrow \uparrow \uparrow \downarrow \ \downarrow \uparrow \downarrow \uparrow \ \uparrow \downarrow \uparrow \downarrow",
#             color=BLUE
#         ).next_to(term_three, DOWN).shift([0, -.5, 0])
#
#         # SCENE
#         self.play(Write(title))
#         self.play(Write(num_group))
#         self.wait(2)
#
#         self.play(Write(se))
#         self.play(Write(frame), Write(se_d))
#         self.wait(5)
#
#         # spin excess example
#         self.play(Write(m1))
#         self.play(Transform(m1[0], m2[0]))
#         self.play(Transform(m1[2], m2[1]))
#         self.play(Transform(m1[4], m2[2]))
#         self.play(Transform(m1[6], m2[3]))
#         self.wait(2)
#         self.play(Unwrite(m1))
#
#         self.play(Write(gen))
#         self.wait(1)
#         self.play(Write(gen_two))
#         self.wait(3)
#         self.play(
#             #Unwrite(se),
#             #Unwrite(frame),
#             #Unwrite(se_d),
#             Unwrite(gen_two)
#         )
#
#         self.play(Transform(gen, gen1))
#         self.wait(.5)
#
#         # self.play(Write(n_up[0]), Write(n_up[1]))
#         # self.wait(2)
#         # self.play(Write(n_frame), Write(frame_tex))
#
#         # self.wait(3)
#         # self.play(Unwrite(n_frame), Unwrite(frame_tex))
#
#         # self.play(Write(n_up[2]))
#         # self.play(Write(n_up[3:4]))
#
#         self.play(Write(binomial[0]))
#         self.wait(0.5)
#         self.play(Write(binomial[1]))
#         self.wait(0.5)
#         self.play(Write(binomial[2]))
#
#         self.play(Unwrite(gen1), Unwrite(gen), Unwrite(num_group), Unwrite(se), Unwrite(frame), Unwrite(se_d))
#
#         self.play(Write(sub))
#         self.wait(1)
#
#         self.play(Transform(binomial, gen_binomial), Unwrite(sub))
#         self.wait(2)
#
#         self.play(Write(gen_frame))
#         self.play(Write(multip_text))
#         self.play(Write(multip))
#         self.wait(2)
#
#         self.play(Write(num_states))
#         self.wait(4)
#
#         self.play(Unwrite(binomial), Unwrite(gen_binomial), Unwrite(gen_frame), Unwrite(multip_text))
#         self.play(num_states.animate.shift([0, 8, 0]), Transform(multip, multip1))
#
#         self.play(Write(four_example))
#         self.play(Write(four_exp[0]))
#         self.wait(1)
#         self.play(Write(four_exp[1]))
#
#         # terms
#         self.play(Write(one_und))
#         self.play(Write(term_one[0]))
#         self.play(Write(term_one[1]))
#         self.play(Write(term_one_symbols))
#
#         self.wait(3)
#         self.play(Unwrite(one_und), Unwrite(term_one), Unwrite(term_one_symbols))
#
#         self.play(Write(three_und))
#         self.play(Write(term_three[0]))
#         self.play(Write(term_three[1]), Write(term_three[2]))
#         self.play(Write(term_three_symbols))
#
#         self.play(Unwrite(four_example), Unwrite(four_exp), Unwrite(three_und), Unwrite(term_three), Unwrite(term_three_symbols), Unwrite(num_states))
#         self.wait(2)
# Out:
# [12/28/23 19:59:20] INFO     Animation 0 : Using cached data (hash :                           ]8;id=412429;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=58714;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4222611999_4276499293_223132457)
# [12/28/23 19:59:21] INFO     Animation 1 : Using cached data (hash :                           ]8;id=220553;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=154459;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_996911804_3187651307)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=396768;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=386333;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_957343386_1552943943)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=336878;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=14036;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_174054837_1076842302)
# [12/28/23 19:59:22] INFO     Animation 4 : Using cached data (hash :                           ]8;id=951118;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=775381;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_1929834099_1844282416)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=971149;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=299172;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_2464823014_3778760293)
# [12/28/23 19:59:23] INFO     Animation 6 : Using cached data (hash :                           ]8;id=28803;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=478295;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_1770892959_3142950836)
#                     INFO     Animation 7 : Using cached data (hash :                           ]8;id=592175;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=995206;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_616518410_2666561270)
# [12/28/23 19:59:24] INFO     Animation 8 : Using cached data (hash :                           ]8;id=147075;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=65128;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_2876289101_4046190958)
# [12/28/23 19:59:26] INFO     Animation 9 : Partial movie file written in                   ]8;id=562783;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=684154;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\partial_movie_files\StateCounting\4245490092_84548002
#                              8_2346345740.mp4'
# [12/28/23 19:59:28] INFO     Animation 10 : Partial movie file written in                  ]8;id=23049;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=702183;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\partial_movie_files\StateCounting\4245490092_38912931
#                              6_573111532.mp4'
# [12/28/23 19:59:29] INFO     Animation 11 : Using cached data (hash :                          ]8;id=803946;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=341038;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_957343386_2309709426)
# [12/28/23 19:59:30] INFO     Animation 12 : Using cached data (hash :                          ]8;id=628172;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=17276;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_2874574070_408967225)
#                     INFO     Animation 13 : Using cached data (hash :                          ]8;id=108527;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=878205;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_338399276_1160721830)
# [12/28/23 19:59:32] INFO     Animation 14 : Partial movie file written in                  ]8;id=637493;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=557318;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\partial_movie_files\StateCounting\4245490092_13293148
#                              81_660293018.mp4'
#                     INFO     Animation 15 : Using cached data (hash :                          ]8;id=665602;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=766060;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_461323974_4070744979)
#                     INFO     Animation 16 : Using cached data (hash :                          ]8;id=452614;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=833329;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_1149804837_1379893879)
# [12/28/23 19:59:33] INFO     Animation 17 : Using cached data (hash :                          ]8;id=197434;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=806915;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_2648475550_1838472970)
#                     INFO     Animation 18 : Using cached data (hash :                          ]8;id=881077;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=84946;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_1060853888_1070316580)
# [12/28/23 19:59:34] INFO     Animation 19 : Using cached data (hash :                          ]8;id=917288;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=308531;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_4070753449_3124976779)
#                     INFO     Animation 20 : Using cached data (hash :                          ]8;id=585553;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=774080;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_3118768115_1280800258)
# [12/28/23 19:59:35] INFO     Animation 21 : Using cached data (hash :                          ]8;id=857193;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=338775;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_4070753449_3194990275)
# [12/28/23 19:59:36] INFO     Animation 22 : Using cached data (hash :                          ]8;id=47472;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=734888;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_1255094844_3480179667)
#                     INFO     Animation 23 : Using cached data (hash :                          ]8;id=736732;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=630438;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_4070753449_4026990503)
# [12/28/23 19:59:37] INFO     Animation 24 : Using cached data (hash :                          ]8;id=268835;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=650277;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_1157993541_2463349201)
# [12/28/23 19:59:38] INFO     Animation 25 : Using cached data (hash :                          ]8;id=120499;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=707147;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_4194665948_1610457484)
#                     INFO     Animation 26 : Using cached data (hash :                          ]8;id=226928;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=767086;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_3709014792_3977232715)
# [12/28/23 19:59:39] INFO     Animation 27 : Using cached data (hash :                          ]8;id=700333;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=346559;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_3213241947_3690004887)
#                     INFO     Animation 28 : Using cached data (hash :                          ]8;id=822438;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=30377;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_2932954662_2525644915)
# [12/28/23 19:59:41] INFO     Animation 29 : Using cached data (hash :                          ]8;id=246137;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=423819;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_957343386_319729331)
#                     INFO     Animation 30 : Using cached data (hash :                          ]8;id=804348;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=818593;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_4293751859_2881810943)
# [12/28/23 19:59:42] INFO     Animation 31 : Using cached data (hash :                          ]8;id=109571;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=169983;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_711544137_2977399434)
#                     INFO     Animation 32 : Using cached data (hash :                          ]8;id=28650;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=532753;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_837206624_1491726697)
# [12/28/23 19:59:43] INFO     Animation 33 : Using cached data (hash :                          ]8;id=771174;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=863317;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_957343386_4112857460)
# [12/28/23 19:59:44] INFO     Animation 34 : Using cached data (hash :                          ]8;id=429574;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=121451;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_1731534522_3050198733)
# [12/28/23 19:59:45] INFO     Animation 35 : Using cached data (hash :                          ]8;id=281383;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=770263;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_4016927065_636870065)
# [12/28/23 19:59:46] INFO     Animation 36 : Using cached data (hash :                          ]8;id=403581;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=889061;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_3540701055_1332129960)
# [12/28/23 19:59:47] INFO     Animation 37 : Using cached data (hash :                          ]8;id=284521;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=356597;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_2649037031_2663162079)
# [12/28/23 19:59:48] INFO     Animation 38 : Using cached data (hash :                          ]8;id=638526;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=702436;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_3861805335_2327136494)
# [12/28/23 19:59:49] INFO     Animation 39 : Using cached data (hash :                          ]8;id=149572;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=59381;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_355498906_196762593)
#                     INFO     Animation 40 : Using cached data (hash :                          ]8;id=835555;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=527338;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_3213241947_835919233)
# [12/28/23 19:59:50] INFO     Animation 41 : Using cached data (hash :                          ]8;id=281746;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=696520;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_2928476138_4081011922)
# [12/28/23 19:59:51] INFO     Animation 42 : Using cached data (hash :                          ]8;id=383534;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=737959;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_1243494414_203429503)
#                     INFO     Animation 43 : Using cached data (hash :                          ]8;id=282249;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=231983;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_2805710060_4098522348)
# [12/28/23 19:59:52] INFO     Animation 44 : Using cached data (hash :                          ]8;id=394553;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=303509;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_2528475780_2808091919)
# [12/28/23 19:59:53] INFO     Animation 45 : Using cached data (hash :                          ]8;id=106601;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=956508;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_3026510080_432495718)
# [12/28/23 19:59:56] INFO     Animation 46 : Partial movie file written in                  ]8;id=493717;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=657859;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\partial_movie_files\StateCounting\4245490092_11498048
#                              37_2956232304.mp4'
# [12/28/23 19:59:57] INFO     Animation 47 : Using cached data (hash :                          ]8;id=808836;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=635779;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_44967607_2816376797)
#                     INFO     Animation 48 : Using cached data (hash :                          ]8;id=93278;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=62557;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_39800053_701784942)
# [12/28/23 19:59:58] INFO     Animation 49 : Using cached data (hash :                          ]8;id=224771;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=67449;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_3134947204_1156757567)
# [12/28/23 19:59:59] INFO     Animation 50 : Using cached data (hash :                          ]8;id=298454;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=370695;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_123607827_1898905040)
# [12/28/23 20:00:00] INFO     Animation 51 : Using cached data (hash :                          ]8;id=452943;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=514960;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4245490092_1028783999_1125036339)
# [12/28/23 20:00:12] INFO     Animation 52 : Partial movie file written in                  ]8;id=283327;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=61853;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\partial_movie_files\StateCounting\4245490092_28931327
#                              56_1325226770.mp4'
# [12/28/23 20:00:13] INFO     Animation 53 : Partial movie file written in                  ]8;id=432691;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=780842;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\partial_movie_files\StateCounting\4245490092_17409190
#                              36_3727786812.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=890993;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=907509;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#607\607]8;;\
# [12/28/23 20:00:14] INFO                                                                   ]8;id=536914;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=817818;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\StateCounting.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=885149;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=556547;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#700\700]8;;\
#                              manim has removed the 6 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered StateCounting                                                    ]8;id=865;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=173587;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 54 animations
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-b678fdca1516> in <module>
# ----> 1 get_ipython().run_cell_magic('manim', '-qh -r 1080,1920 StateCounting', '\nclass StateCounting(Scene):\n    def construct(self):\n        myTemplate = TexTemplate()\n        myTemplate.add_to_preamble(r"\\usepackage{amsmath}")\n\n        title = Text("Counting States", color=BLUE).shift([0,8,0])\n\n        up_d = Text("# of states with +m").scale(.7).shift([-3, 6, 0])\n        up_t = MathTex(\n            r"N_{\\uparrow} = \\frac{1}{2}N + s"\n        ).next_to(up_d, DOWN)\n\n        down_d = Text("# of states with -m").scale(.7).shift([3, 6, 0])\n        down_t = MathTex(\n            r"N_{\\downarrow} = \\frac{1}{2}N - s"\n        ).next_to(down_d, DOWN)\n        num_group = VGroup(up_d, up_t, down_d, down_t)\n\n        se = MathTex(\n            r"N_{\\uparrow} - N_{\\downarrow} = 2s"\n        ).shift([0,3.5,0])\n        frame = SurroundingRectangle(se[0][6:8], buff=.1, color=BLUE)\n        se_d = Text("Spin Excess", color=BLUE).next_to(frame, DOWN).scale(.7)\n\n        m1 = MathTex(\n            r"&M = 3m",\n            r"&\\uparrow_1 \\uparrow_2 \\uparrow_3 \\\\",\n            r"&M = m",  \n            r"&\\uparrow_1 \\uparrow_2 \\downarrow_3 \\ \\ \\uparrow_1 \\downarrow_2 \\uparrow_3 \\ \\ \\downarrow_1 \\uparrow_2 \\uparrow_3 \\\\",\n            r"&M = -m",  \n            r"&\\uparrow_1 \\downarrow_2 \\downarrow_3 \\ \\ \\downarrow_1 \\uparrow_2 \\downarrow_3 \\ \\ \\downarrow_1 \\downarrow_2 \\uparrow_3 \\\\",\n            r"&M = -3m", \n            r"&\\downarrow_1 \\downarrow_2 \\downarrow_3 \\\\",\n        ).next_to(se_d, DOWN).shift([-1.5, -1, 0])\n\n\n        m2 = MathTex(\n            r"&2s = 3 \\\\",\n            r"&2s = 1 \\\\",\n            r"&2s = -1 \\\\",\n            r"&2s = -3 \\\\"\n        ).shift(m1.get_critical_point(UL)).shift([1, -1.215, 0])\n\n        gen = MathTex(\n            r"(\\uparrow + \\downarrow)^N"\n        ).shift([0,1,0])\n\n        gen1 = MathTex(\n            r"(\\uparrow + \\downarrow)^N = \\ ?"\n        )\n\n        gen_two = MathTex(\n            r"(\\uparrow + \\downarrow)^2 = \\uparrow \\uparrow + 2\\uparrow \\downarrow + \\downarrow \\downarrow"\n        ).next_to(gen, DOWN)\n\n        # n choose N_up\n        n_up = MathTex(\n            r"{N \\choose N_{\\uparrow}}",\n            r"&= \\frac{N!}{(N-N_\\uparrow)! N_{\\uparrow}!}"\n            r"= \\frac{N!}{N_{\\downarrow}! N_{\\uparrow}!} \\\\ \\\\",\n            r"{N \\choose s} &= \\frac{N!}{(\\frac{1}{2}N - s)!(\\frac{1}{2}N + s)}",\n            r"= \\frac{N!}{N_{\\downarrow}! N_{\\uparrow}!}"\n        ).next_to(gen1, DOWN).shift([0, -1, 0])\n\n        n_frame = Underline(n_up[1][4:9], color=BLUE)\n        frame_tex = MathTex(\n            r"N_{\\downarrow}"\n        ).next_to(n_frame, DOWN)\n\n        # s_up = MathTex(\n        #     r"{N \\choose s} = \\frac{N!}{(\\frac{1}{2}N - s)!(\\frac{1}{2}N + s)}",\n        # ).next_to(n_up, DOWN)\n\n        binomial = MathTex(\n            r"(x + y)^N &= \\sum^N_{t=0} {N \\choose t} x^{N-t}y^t \\\\",\n            r"&= x^N + N x^{N-1} y + \\frac{1}{2} N(N-1) x^{N-2} y^2 + ... + y^N \\\\",\n            r"&= \\sum^N_{t=0} \\frac{N!}{(N-t)!t!} x^{N-t} y^t \\\\"\n        ).next_to(gen, DOWN).shift([0,-1,0])\n\n        sub = MathTex(\n            r"t \\rightarrow \\frac{1}{2}N - s"\n        )\n\n        gen_binomial = MathTex(\n            r"(\\uparrow + \\downarrow)^N &= \\sum^{\\frac{1}{2}N}_{s=-\\frac{1}{2}N} {N \\choose s} \\uparrow^{\\frac{1}{2}N + s}\\downarrow^{\\frac{1}{2}N - s} \\\\",\n            r"&= \\sum_s \\frac{N!}{(\\frac{1}{2}N + s)!(\\frac{1}{2}N - s)!} \\uparrow^{\\frac{1}{2}N + s}\\downarrow^{\\frac{1}{2}N - s} \\\\"\n        ).center().shift([0, 2, 0])\n\n        sub = MathTex(\n            r"t \\rightarrow \\frac{1}{2}N - s"\n        ).next_to(binomial, DOWN)\n\n        gen_frame = SurroundingRectangle(gen_binomial[1][3:10], buff=.1, color=BLUE)\n\n        multip_text = Text("Multiplicity Function", color=BLUE).next_to(gen_binomial, DOWN).shift([0, -1, 0])\ ...
#
# c:\Users\Zach\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2360             with self.builtin_trap:
#    2361                 args = (magic_arg_s, cell)
# -> 2362                 result = fn(*args, **kwargs)
#    2363             return result
#    2364
#
# c:\Users\Zach\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# c:\Users\Zach\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\ipython_magic.py in manim(self, line, cell, local_ns)
#     189                         tmpfile,
#     190                         html_attributes=f'controls autoplay loop style="max-width: {config["media_width"]};"',
# --> 191                         embed=embed,
#     192                     )
#     193
#
# TypeError: __init__() got an unexpected keyword argument 'html_attributes'

# %%
# %%manim -qh -r 1080,1920 Approximation
#
# class Approximation(Scene):
#     def construct(self):
#         title = Text("Counting States", color=BLUE).shift([0,8,0])
#         multip1 = MathTex(
#             r"g(N,s) = \frac{N!}{N_{\uparrow}! N_{\downarrow}!}"
#         ).shift([0, 5.5, 0])
#
#         approx = Text("Approximation: ", color=BLUE).shift([0, 3.5, 0]).scale(.8)
#         sterling_res = MathTex(
#             r"g(N, s) \approx \left(\frac{2}{\pi N}\right)^{1/2} 2^N \exp \left(\frac{-2s^2}{N}\right)"
#         ).next_to(approx, DOWN).shift([0, -.5, 0])
#
#         self.add(title)
#         self.add(multip1)
#         self.play(Write(approx), Write(sterling_res))
#         self.wait(2)
#         self.play(Unwrite(approx), Unwrite(sterling_res), Unwrite(title), Unwrite(multip1))
# Out:
# [12/28/23 21:30:31] INFO     Animation 0 : Using cached data (hash :                           ]8;id=99623;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=332143;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\renderer\cairo_renderer.py#77\77]8;;\
#                              4222611999_3553716521_583126288)
# [12/28/23 21:30:32] INFO     Animation 1 : Partial movie file written in                   ]8;id=24594;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=79566;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\partial_movie_files\Approximation\4245490092_95734338
#                              6_2089653748.mp4'
# [12/28/23 21:30:37] INFO     Animation 2 : Partial movie file written in                   ]8;id=814986;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=218780;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#516\516]8;;\
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\partial_movie_files\Approximation\4245490092_80411560
#                              3_292186046.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=569946;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=362340;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#607\607]8;;\
#                     INFO                                                                   ]8;id=242782;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=377361;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'C:\Users\Zach\code\Physics\src\thermal\media\videos\thermal\
#                              1920p60\Approximation.mp4'
#                     INFO     Rendered Approximation                                                    ]8;id=752557;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=676743;file://c:\Users\Zach\Anaconda3\lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 3 animations
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-f3b155d8aff2> in <module>
# ----> 1 get_ipython().run_cell_magic('manim', '-qh -r 1080,1920 Approximation', '\nclass Approximation(Scene):\n    def construct(self):\n        title = Text("Counting States", color=BLUE).shift([0,8,0])        \n        multip1 = MathTex(\n            r"g(N,s) = \\frac{N!}{N_{\\uparrow}! N_{\\downarrow}!}"\n        ).shift([0, 5.5, 0])\n\n        approx = Text("Approximation: ", color=BLUE).shift([0, 3.5, 0]).scale(.8)\n        sterling_res = MathTex(\n            r"g(N, s) \\approx \\left(\\frac{2}{\\pi N}\\right)^{1/2} 2^N \\exp \\left(\\frac{-2s^2}{N}\\right)"\n        ).next_to(approx, DOWN).shift([0, -.5, 0])\n\n        self.add(title)\n        self.add(multip1)\n        self.play(Write(approx), Write(sterling_res))\n        self.wait(2)\n        self.play(Unwrite(approx), Unwrite(sterling_res), Unwrite(title), Unwrite(multip1))\n')
#
# c:\Users\Zach\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2360             with self.builtin_trap:
#    2361                 args = (magic_arg_s, cell)
# -> 2362                 result = fn(*args, **kwargs)
#    2363             return result
#    2364
#
# c:\Users\Zach\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# c:\Users\Zach\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# c:\Users\Zach\Anaconda3\lib\site-packages\manim\utils\ipython_magic.py in manim(self, line, cell, local_ns)
#     189                         tmpfile,
#     190                         html_attributes=f'controls autoplay loop style="max-width: {config["media_width"]};"',
# --> 191                         embed=embed,
#     192                     )
#     193
#
# TypeError: __init__() got an unexpected keyword argument 'html_attributes'
